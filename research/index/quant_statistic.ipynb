# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns

import os
from quant_free.dataset.us_equity_load import *

import seaborn as sns
mpl.rcParams['font.sans-serif'] = ['KaiTi', 'SimHei', 'FangSong']  # 汉字字体,优先使用楷体，如果找不到楷体，则使用黑体
mpl.rcParams['font.size'] = 14  # 字体大小
mpl.rcParams['axes.unicode_minus'] = False  # 正常显示负号

import quantstats_lumi as qs

# %% [markdown]
# qs.reports.metrics(mode='basic|full", ...) - shows basic/full metrics
#
# qs.reports.plots(mode='basic|full", ...) - shows basic/full plots
#
# qs.reports.basic(...) - shows basic metrics and plots
#
# qs.reports.full(...) - shows full metrics and plots
#
# qs.reports.html(...) - generates a complete report as html

# %%
# Set font to DejaVu Sans or SimHei
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']  # or 'SimHei' for Chinese font support
plt.rcParams['axes.unicode_minus'] = False

# Proceed with your seaborn/matplotlib plotting
sns.set()

ret= us_dir1_load_csv(dir0 = 'symbol', dir1 = 'xq', filename='xq_index_price_ratio.csv')

metrics = qs.reports.metrics(ret, mode='basic', display = False, as_pct = True)

metrics = metrics.T.sort_values(by='CAGR% (Annual Return)', axis=0, ascending=False).T

us_dir1_store_csv(dir0 = 'symbol', dir1 = 'xq', filename='xq_index_analysis' + '.csv', data = metrics, encoding='utf-8-sig')

display(metrics)
# Display DataFrame in a scrollable box
# output = widgets.Output()
# with output:
#     display(metrics)
    
# scrollable = widgets.VBox([output])
# display(scrollable)
# Out:
#                          半导体产品与设备       建筑与工程     互动媒体与服务          汽车  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                 283%        197%        157%        152%
# CAGR% (Annual Return)       33.19       26.17       22.37       21.84
# Sharpe                       1.12        1.07        0.92        0.68
# RoMaD                        0.67        0.55        0.55        0.28
# Prob. Sharpe Ratio          97.79       96.95       95.37       94.21
# Sortino                      1.66         1.5        1.38        1.38
# Sortino/√2                   1.17        1.06        0.98        0.98
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown                -49.9      -47.91      -40.62      -77.42
# Longest DD Days               526         266         615         743
# MTD                        -13.06       -9.67       -5.98       -1.73
# 3M                         -14.37       -4.75      -10.18        8.45
# 6M                           5.04        6.84       10.26        1.63
# YTD                         44.35        19.5       13.54       -7.48
# 1Y                          65.03       22.15       18.91       -8.23
# 3Y (ann.)                   30.56       20.83       11.13       -3.92
# 5Y (ann.)                   33.19       26.17       22.37       21.84
# 10Y (ann.)                  33.19       26.17       22.37       21.84
# All-time (ann.)             33.19       26.17       22.37       21.84
# Avg. Drawdown               -5.31       -4.02       -3.73       -9.05
# Avg. Drawdown Days             25          20          22          53
# Recovery Factor               3.4        2.78        2.98        2.71
# Ulcer Index                  0.18        0.11        0.14        0.45
# Serenity Index                0.7        1.23        0.74        0.29
#
#                          贸易公司与经销商     电脑与外围设备     家庭耐用消费品          软件  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                 147%        144%        119%        116%
# CAGR% (Annual Return)       21.35       20.96       18.24        17.9
# Sharpe                        1.0        0.92        0.79        0.86
# RoMaD                         0.5        0.63        0.35        0.43
# Prob. Sharpe Ratio          96.31       95.07        92.1        93.7
# Sortino                      1.45        1.35        1.14        1.22
# Sortino/√2                   1.02        0.95        0.81        0.86
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -42.89      -33.21      -52.17      -41.65
# Longest DD Days               391         542         713         785
# MTD                         -5.79        -3.7       -2.79        -3.6
# 3M                           3.34        9.66        12.0        -0.4
# 6M                           0.45       25.41       13.16        0.58
# YTD                         10.67       12.64        17.3        6.31
# 1Y                          32.18       14.13       41.75       17.86
# 3Y (ann.)                   21.38       12.52       17.65        6.37
# 5Y (ann.)                   21.35       20.96       18.24        17.9
# 10Y (ann.)                  21.35       20.96       18.24        17.9
# All-time (ann.)             21.35       20.96       18.24        17.9
# Avg. Drawdown               -4.86        -5.4       -5.04       -3.64
# Avg. Drawdown Days             32          37          33          27
# Recovery Factor              2.54        3.38        2.05        2.33
# Ulcer Index                   0.1        0.12        0.19        0.17
# Serenity Index               1.08         0.8        0.37        0.32
#
#                       独立电力生产商与能源贸易商   商业服务与商业用品        建筑产品      工业REIT  \
# Start Period             2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period               2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                    0           0           0           0
# Time in Market                100.0       100.0       100.0       100.0
# Total Return                   100%         95%         94%         85%
# CAGR% (Annual Return)         15.93       15.35       15.19        14.1
# Sharpe                         0.79        0.93        0.73         0.7
# RoMaD                          0.36        0.41        0.36        0.36
# Prob. Sharpe Ratio            92.32       94.94       90.49        89.6
# Sortino                        1.15        1.29        1.04        1.02
# Sortino/√2                     0.81        0.91        0.74        0.72
# Omega                          1.08        1.08        1.08        1.08
# Max Drawdown                  -44.5       -37.0      -42.55      -39.53
# Longest DD Days                 534         575         710         978
# MTD                           -3.23       -3.34       -5.54       -0.87
# 3M                            -1.92        4.99       -0.95        15.7
# 6M                            22.04        8.59       -6.52       -0.29
# YTD                           29.61       18.36        1.87       -2.13
# 1Y                            43.79       32.51       18.29        6.26
# 3Y (ann.)                     16.51        13.8        9.47        6.23
# 5Y (ann.)                     15.93       15.35       15.19        14.1
# 10Y (ann.)                    15.93       15.35       15.19        14.1
# All-time (ann.)               15.93       15.35       15.19        14.1
# Avg. Drawdown                 -5.29       -2.11       -4.43       -3.54
# Avg. Drawdown Days               47          21          33          34
# Recovery Factor                1.99         2.1         2.1        2.12
# Ulcer Index                    0.11        0.09        0.16        0.15
# Serenity Index                  0.8         0.7        0.38        0.42
#
#                              电气设备          制药        建筑材料      工业集团企业  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  85%         84%         79%         77%
# CAGR% (Annual Return)        14.1       13.91        13.2        13.0
# Sharpe                        0.7        0.96        0.66        0.61
# RoMaD                        0.31        0.52        0.26        0.32
# Prob. Sharpe Ratio          89.62       95.78       88.03       89.84
# Sortino                       1.0        1.43        0.93        1.14
# Sortino/√2                   0.71        1.01        0.66         0.8
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -44.75      -26.88      -49.88      -40.83
# Longest DD Days               780         359         541        1034
# MTD                         -7.28       -3.29       -6.25       -5.03
# 3M                         -10.59        5.04       -1.97        1.85
# 6M                          -6.57        9.55       -7.51        6.64
# YTD                          2.78       21.98        6.18        9.99
# 1Y                           5.97       22.83       19.88       21.69
# 3Y (ann.)                    5.69       14.34       12.36         2.1
# 5Y (ann.)                    14.1       13.91        13.2        13.0
# 10Y (ann.)                   14.1       13.91        13.2        13.0
# All-time (ann.)              14.1       13.91        13.2        13.0
# Avg. Drawdown               -3.79       -3.16       -5.74        -6.8
# Avg. Drawdown Days             26          30          37          87
# Recovery Factor              1.87        2.57        1.64        2.03
# Ulcer Index                  0.12        0.06        0.16        0.18
# Serenity Index               0.59        1.29        0.34        0.32
#
#                        医疗保健提供商与服务    医疗保健REIT        资本市场        居家用品  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  72%         72%         70%         55%
# CAGR% (Annual Return)        12.3       12.27       11.99        9.79
# Sharpe                       0.71        0.61        0.65        0.64
# RoMaD                        0.33        0.22        0.28         0.4
# Prob. Sharpe Ratio          89.76       86.05       87.81       88.62
# Sortino                      1.02        0.86        0.92        1.01
# Sortino/√2                   0.72        0.61        0.65        0.72
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown                -37.8       -56.9       -43.4      -24.57
# Longest DD Days               408         766        1000         873
# MTD                         -1.13        1.21       -4.72        2.14
# 3M                          10.65       16.73        0.36         7.7
# 6M                          14.42       41.18        5.18       15.02
# YTD                         11.99       53.19        8.05       22.61
# 1Y                          19.71       69.55       21.12       18.42
# 3Y (ann.)                   11.62       20.68        1.84        6.86
# 5Y (ann.)                    12.3       12.27       11.99        9.79
# 10Y (ann.)                   12.3       12.27       11.99        9.79
# All-time (ann.)              12.3       12.27       11.99        9.79
# Avg. Drawdown               -4.34       -3.86       -4.37       -3.51
# Avg. Drawdown Days             40          50          43          60
# Recovery Factor              1.82        1.47        1.66        2.22
# Ulcer Index                  0.07        0.17        0.17        0.09
# Serenity Index               1.06        0.34        0.26        0.53
#
#                              专营零售      信息技术服务      无线电信业务      医疗保健技术  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  52%         52%         52%         49%
# CAGR% (Annual Return)         9.4         9.4        9.29        8.94
# Sharpe                       0.56        0.54         0.6        0.51
# RoMaD                        0.22        0.18         0.3        0.14
# Prob. Sharpe Ratio           83.9       83.28       85.96       81.87
# Sortino                      0.76        0.76        0.86        0.73
# Sortino/√2                   0.54        0.54        0.61        0.52
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -43.41       -53.4      -31.15      -62.31
# Longest DD Days               999        1025        1160        1299
# MTD                         -2.63       -6.04       -1.63       -2.34
# 3M                           7.55        3.73        3.18        12.6
# 6M                           1.81       -6.21        7.88       -1.66
# YTD                         10.84        2.99        11.4        4.53
# 1Y                           14.7       14.82       21.83       -6.58
# 3Y (ann.)                    2.07       -6.07        3.38      -14.15
# 5Y (ann.)                     9.4         9.4        9.29        8.94
# 10Y (ann.)                    9.4         9.4        9.29        8.94
# All-time (ann.)               9.4         9.4        9.29        8.94
# Avg. Drawdown                -4.3       -5.01       -4.64        -5.6
# Avg. Drawdown Days             43          40          59          49
# Recovery Factor              1.38        1.19        1.74        1.08
# Ulcer Index                  0.18         0.3        0.11         0.4
# Serenity Index               0.17        0.08        0.41        0.05
#
#                              专业服务        机械制造  电子设备、仪器和元件          保险  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  42%         42%         41%         41%
# CAGR% (Annual Return)        7.84        7.73        7.67        7.65
# Sharpe                       0.52        0.48        0.49        0.51
# RoMaD                        0.21        0.17         0.2        0.17
# Prob. Sharpe Ratio          82.44        80.7       80.75       81.64
# Sortino                      0.74         0.7        0.68         0.7
# Sortino/√2                   0.52         0.5        0.48        0.49
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -37.54      -44.76      -38.85      -44.84
# Longest DD Days               982        1271        1025         602
# MTD                         -2.65       -6.04       -7.48       -1.03
# 3M                            8.8        1.77       -5.15        9.41
# 6M                          -2.22       -0.01       -1.27       10.26
# YTD                           2.1        8.41        2.88       18.39
# 1Y                            5.9        10.0        8.57       24.69
# 3Y (ann.)                    0.21        2.77       -0.81        8.79
# 5Y (ann.)                    7.84        7.73        7.67        7.65
# 10Y (ann.)                   7.84        7.73        7.67        7.65
# All-time (ann.)              7.84        7.73        7.67        7.65
# Avg. Drawdown               -2.99       -5.53       -4.43       -3.61
# Avg. Drawdown Days             34          72          52          39
# Recovery Factor              1.31        1.24        1.37         1.1
# Ulcer Index                  0.16        0.16        0.17        0.12
# Serenity Index               0.17        0.23        0.18        0.28
#
#                            零售REIT     能源设备与服务   生命科学工具和服务    房地产管理和开发  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  40%         40%         40%         35%
# CAGR% (Annual Return)         7.4        7.39        7.39        6.67
# Sharpe                       0.46        0.48        0.48        0.43
# RoMaD                        0.13         0.1        0.15        0.13
# Prob. Sharpe Ratio          79.29       80.52       80.57        78.2
# Sortino                      0.65         0.7        0.69        0.62
# Sortino/√2                   0.46         0.5        0.49        0.44
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -56.45      -74.21      -48.16      -52.74
# Longest DD Days               944         730        1096        1299
# MTD                         -1.08       -7.49       -2.62        -1.8
# 3M                          13.37       -5.78       -0.56        14.4
# 6M                          15.54       -9.09       -2.45        7.04
# YTD                         18.02      -13.32         4.4        2.96
# 1Y                          34.44       -21.8        2.48       10.39
# 3Y (ann.)                   11.01       21.89       -8.61      -10.37
# 5Y (ann.)                     7.4        7.39        7.39        6.67
# 10Y (ann.)                    7.4        7.39        7.39        6.67
# All-time (ann.)               7.4        7.39        7.39        6.67
# Avg. Drawdown               -6.87       -9.86       -4.69        -6.3
# Avg. Drawdown Days             97          65          46          67
# Recovery Factor              1.17        1.29        1.05        1.07
# Ulcer Index                  0.23         0.3        0.24        0.34
# Serenity Index               0.17         0.2        0.08        0.06
#
#                              消费信贷 石油、天然气与消费用燃料      交通基本设施      专门REIT  \
# Start Period           2020-01-02   2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06   2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0            0           0           0
# Time in Market              100.0        100.0       100.0       100.0
# Total Return                  34%          31%         31%         29%
# CAGR% (Annual Return)        6.51         6.01        5.93        5.66
# Sharpe                       0.43         0.41        0.42        0.41
# RoMaD                        0.12          0.1        0.09        0.14
# Prob. Sharpe Ratio          77.97        76.96        77.1       76.91
# Sortino                      0.62         0.57        0.58        0.59
# Sortino/√2                   0.44          0.4        0.41        0.42
# Omega                        1.08         1.08        1.08        1.08
# Max Drawdown               -54.36       -60.29      -64.43      -40.23
# Longest DD Days              1075          822         755         978
# MTD                          -5.3        -5.48       -4.27        0.94
# 3M                           3.99        -2.98      -12.18       14.17
# 6M                            8.1         0.37        0.68        11.0
# YTD                         18.36         1.64       -11.4        7.39
# 1Y                          39.66        -2.91       -8.74       22.52
# 3Y (ann.)                   -1.05        10.86       12.91       -0.43
# 5Y (ann.)                    6.51         6.01        5.93        5.66
# 10Y (ann.)                   6.51         6.01        5.93        5.66
# All-time (ann.)              6.51         6.01        5.93        5.66
# Avg. Drawdown               -6.34        -5.92      -11.37       -4.69
# Avg. Drawdown Days             63           71          86          55
# Recovery Factor              1.17         0.93        0.99        1.05
# Ulcer Index                  0.24         0.21        0.22         0.2
# Serenity Index               0.15         0.16        0.17         0.1
#
#                              化学制品      电力公用事业        生物科技        通信设备  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  29%         27%         26%         25%
# CAGR% (Annual Return)        5.64        5.15        5.03        4.89
# Sharpe                       0.41        0.39        0.38        0.38
# RoMaD                        0.14        0.14        0.11        0.14
# Prob. Sharpe Ratio          76.74       76.07        75.2       75.08
# Sortino                      0.58        0.57        0.56        0.53
# Sortino/√2                   0.41         0.4         0.4        0.38
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -39.92      -37.78      -47.88      -35.85
# Longest DD Days              1255         747        1072         982
# MTD                         -4.74        1.13       -4.02       -4.58
# 3M                          -1.33       10.82       -0.89        8.64
# 6M                          -0.57       26.04        6.04        7.29
# YTD                          1.04       20.66         3.6        5.18
# 1Y                           4.47       24.66        9.24        2.24
# 3Y (ann.)                    0.09        4.37      -11.37        1.67
# 5Y (ann.)                    5.64        5.15        5.03        4.89
# 10Y (ann.)                   5.64        5.15        5.03        4.89
# All-time (ann.)              5.64        5.15        5.03        4.89
# Avg. Drawdown               -6.65       -6.69       -5.57       -5.75
# Avg. Drawdown Days            104          86          58          60
# Recovery Factor              1.08         1.0        0.96        1.07
# Ulcer Index                  0.13        0.13        0.29        0.19
# Serenity Index               0.26        0.19        0.06         0.1
#
#                          酒店、餐馆与休闲         经销商     航空货运与物流       水公用事业  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  23%         21%         20%         20%
# CAGR% (Annual Return)        4.44         4.2        3.98        3.92
# Sharpe                       0.36        0.35        0.34        0.33
# RoMaD                        0.09        0.09        0.11        0.11
# Prob. Sharpe Ratio          73.87       73.28       72.76       72.61
# Sortino                       0.5        0.49        0.49        0.48
# Sortino/√2                   0.35        0.34        0.35        0.34
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown                -49.0      -46.87      -37.54       -34.6
# Longest DD Days              1034        1023        1193         978
# MTD                         -2.45       -2.63       -2.59        0.51
# 3M                           0.02       -4.14       -0.46       10.98
# 6M                          -1.23      -18.98       -2.76       15.77
# YTD                          0.03      -15.61       -7.97        7.39
# 1Y                           6.62      -14.69      -11.66       11.11
# 3Y (ann.)                   -0.18      -11.77        -6.6        2.06
# 5Y (ann.)                    4.44         4.2        3.98        3.92
# 10Y (ann.)                   4.44         4.2        3.98        3.92
# All-time (ann.)              4.44         4.2        3.98        3.92
# Avg. Drawdown               -7.13       -4.35       -6.34       -7.63
# Avg. Drawdown Days             97          36          86         151
# Recovery Factor              0.76        0.88        1.03        0.99
# Ulcer Index                  0.14        0.25        0.22        0.13
# Serenity Index               0.18        0.07        0.09        0.22
#
#                           纸类与林业产品          娱乐          烟草        航空公司  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0        12.0
# Total Return                  20%         19%         16%         13%
# CAGR% (Annual Return)        3.88        3.77        3.19         2.7
# Sharpe                       0.34        0.33         0.3        0.42
# RoMaD                        0.08        0.06        0.09        0.03
# Prob. Sharpe Ratio          72.53       72.43       70.69       85.74
# Sortino                      0.46        0.46        0.41        1.54
# Sortino/√2                   0.33        0.33        0.29        1.09
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -46.25      -63.22      -36.08      -89.49
# Longest DD Days              1215        1038         929        1665
# MTD                         -3.98       -4.38        1.84       -6.67
# 3M                          -2.89       -3.13       20.12      269.52
# 6M                          -5.21        0.82       34.88      269.52
# YTD                         -2.29       22.74       31.79      269.52
# 1Y                           11.7       34.75       25.57      269.52
# 3Y (ann.)                   -2.22      -11.87        6.54       56.45
# 5Y (ann.)                    3.88        3.77        3.19         2.7
# 10Y (ann.)                   3.88        3.77        3.19         2.7
# All-time (ann.)              3.88        3.77        3.19         2.7
# Avg. Drawdown               -5.26       -5.88      -10.45      -35.88
# Avg. Drawdown Days             62          54         209         567
# Recovery Factor              0.85        0.65        0.73        2.58
# Ulcer Index                  0.24        0.37        0.16        0.67
# Serenity Index               0.07        0.03        0.09        0.34
#
#                              商业银行     复合型公用事业     航空航天与国防          食品  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  12%         11%         10%          9%
# CAGR% (Annual Return)        2.43        2.32        2.07        1.87
# Sharpe                       0.27        0.26        0.27        0.23
# RoMaD                        0.05        0.07        0.04        0.07
# Prob. Sharpe Ratio          68.88       67.91       68.78       66.16
# Sortino                      0.39        0.37         0.4        0.32
# Sortino/√2                   0.28        0.26        0.28        0.23
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -47.61      -34.33      -49.73      -26.26
# Longest DD Days               928         880        1399         488
# MTD                         -3.84        1.54       -4.17        2.86
# 3M                           5.76       16.71        1.49         9.5
# 6M                           9.51       19.97        6.16        9.26
# YTD                         12.78       18.99        2.38        8.02
# 1Y                          28.49       24.24       13.78         8.3
# 3Y (ann.)                    2.02        4.57        7.34        1.75
# 5Y (ann.)                    2.43        2.32        2.07        1.87
# 10Y (ann.)                   2.43        2.32        2.07        1.87
# All-time (ann.)              2.43        2.32        2.07        1.87
# Avg. Drawdown                -8.5       -5.89       -6.62       -4.41
# Avg. Drawdown Days            111         128         119          68
# Recovery Factor              0.65        0.68        0.69        0.63
# Ulcer Index                   0.2        0.15        0.18         0.1
# Serenity Index               0.08        0.09        0.13        0.11
#
#                            住宅REIT      燃气公用事业  酒店及度假村REIT 股权房地产投资信托 （REITs）  \
# Start Period           2020-01-02  2020-01-02  2020-01-02        2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06        2024-09-06
# Risk-Free Rate                  0           0           0                 0
# Time in Market              100.0       100.0       100.0             100.0
# Total Return                   8%          6%          2%               -4%
# CAGR% (Annual Return)        1.71        1.33         0.4             -0.88
# Sharpe                       0.24        0.22        0.24              0.16
# RoMaD                        0.04        0.04        0.01             -0.02
# Prob. Sharpe Ratio          66.82       65.24       66.39             61.26
# Sortino                      0.34        0.31        0.34              0.22
# Sortino/√2                   0.24        0.22        0.24              0.15
# Omega                        1.08        1.08        1.08              1.08
# Max Drawdown               -43.46       -34.9      -55.33             -54.5
# Longest DD Days               976         822         664               892
# MTD                         -1.32       -0.82       -0.48             -1.04
# 3M                          12.81        8.86        1.09             12.84
# 6M                          17.08       11.18        -9.2             18.58
# YTD                         15.44        11.6      -10.14              9.94
# 1Y                          16.66       15.68       -7.56             22.14
# 3Y (ann.)                   -2.91        6.16        5.41             -0.68
# 5Y (ann.)                    1.71        1.33         0.4             -0.88
# 10Y (ann.)                   1.71        1.33         0.4             -0.88
# All-time (ann.)              1.71        1.33         0.4             -0.88
# Avg. Drawdown                -4.5        -6.3       -9.42            -15.77
# Avg. Drawdown Days             60         140         128               281
# Recovery Factor              0.61        0.63        0.61              0.36
# Ulcer Index                  0.25        0.14         0.2              0.22
# Serenity Index               0.05        0.12        0.11              0.05
#
#                           休闲设备与用品   食品与主要用品零售  纺织品、服装与奢侈品          媒体  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  -9%        -17%        -20%        -22%
# CAGR% (Annual Return)       -1.96       -3.87       -4.67       -5.14
# Sharpe                       0.11       -0.07        0.01       -0.14
# RoMaD                       -0.04        -0.1       -0.09       -0.11
# Prob. Sharpe Ratio          58.11       45.14       50.92        40.2
# Sortino                      0.16       -0.09        0.02       -0.18
# Sortino/√2                   0.11       -0.06        0.01       -0.13
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -50.69      -39.43      -52.07      -45.85
# Longest DD Days              1025         870        1034        1100
# MTD                         -3.94       -0.81       -3.77       -2.94
# 3M                           2.53       -0.67      -12.81        3.32
# 6M                           7.23       -10.2      -17.76        0.31
# YTD                          1.86       -7.34      -20.56       -4.43
# 1Y                         -11.76        4.71      -10.22         0.1
# 3Y (ann.)                  -12.18       -8.93      -15.48      -14.42
# 5Y (ann.)                   -1.96       -3.87       -4.67       -5.14
# 10Y (ann.)                  -1.96       -3.87       -4.67       -5.14
# All-time (ann.)             -1.96       -3.87       -4.67       -5.14
# Avg. Drawdown               -6.18       -6.68       -7.65       -5.27
# Avg. Drawdown Days             56          92          74          74
# Recovery Factor              0.28        0.15        0.03        0.27
# Ulcer Index                   0.3        0.22         0.3        0.29
# Serenity Index               0.02       -0.01           0       -0.01
#
#                                饮料       汽车零配件      综合电信业务     综合消费者服务  \
# Start Period           2020-01-02  2020-01-02  2020-01-02  2020-01-02
# End Period             2024-09-06  2024-09-06  2024-09-06  2024-09-06
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                 -26%        -27%        -30%        -32%
# CAGR% (Annual Return)       -6.27       -6.41       -7.42       -8.04
# Sharpe                      -0.17         0.2       -0.38         0.2
# RoMaD                       -0.13       -0.09       -0.17       -0.09
# Prob. Sharpe Ratio          38.13       63.87        24.5        65.5
# Sortino                     -0.23        0.28       -0.53        0.42
# Sortino/√2                  -0.16         0.2       -0.37        0.29
# Omega                        1.08        1.08        1.08        1.08
# Max Drawdown               -48.64      -69.75      -44.24      -87.04
# Longest DD Days              1186         963        1709        1275
# MTD                          1.17      -10.33        1.91       -2.49
# 3M                          -0.79      -30.93        5.18       -1.03
# 6M                           0.37      -32.49        5.88       -6.16
# YTD                         -8.36      -43.98        8.34         0.4
# 1Y                          -5.85      -37.33       19.86       19.02
# 3Y (ann.)                   -3.83      -22.35       -6.45        1.89
# 5Y (ann.)                   -6.27       -6.41       -7.42       -8.04
# 10Y (ann.)                  -6.27       -6.41       -7.42       -8.04
# All-time (ann.)             -6.27       -6.41       -7.42       -8.04
# Avg. Drawdown              -27.68      -16.13      -44.24      -11.46
# Avg. Drawdown Days            567         111        1709         111
# Recovery Factor              0.33        0.62        0.63        0.64
# Ulcer Index                  0.23        0.38        0.27        0.71
# Serenity Index              -0.03        0.07       -0.03        0.03
#
#                       抵押房地产投资信托（REITs）     写字楼REIT
# Start Period                2020-01-02  2020-01-02
# End Period                  2024-09-06  2024-09-06
# Risk-Free Rate                       0           0
# Time in Market                   100.0       100.0
# Total Return                      -38%        -39%
# CAGR% (Annual Return)            -9.78      -10.08
# Sharpe                           -0.06       -0.17
# RoMaD                            -0.14       -0.17
# Prob. Sharpe Ratio               45.77       37.82
# Sortino                          -0.08       -0.24
# Sortino/√2                       -0.06       -0.17
# Omega                             1.08        1.08
# Max Drawdown                    -70.94      -59.77
# Longest DD Days                   1660         976
# MTD                              -1.18        -2.9
# 3M                                5.76        9.91
# 6M                                5.08        4.46
# YTD                               0.69        0.31
# 1Y                                0.28        8.52
# 3Y (ann.)                       -10.55      -14.75
# 5Y (ann.)                        -9.78      -10.08
# 10Y (ann.)                       -9.78      -10.08
# All-time (ann.)                  -9.78      -10.08
# Avg. Drawdown                   -12.24      -18.06
# Avg. Drawdown Days                 280         281
# Recovery Factor                   0.13        0.38
# Ulcer Index                        0.4        0.35
# Serenity Index                   -0.01       -0.02

# %%
# Set font to DejaVu Sans or SimHei
plt.rcParams['font.sans-serif'] = ['DejaVu Sans']  # or 'SimHei' for Chinese font support
plt.rcParams['axes.unicode_minus'] = False

# Proceed with your seaborn/matplotlib plotting
sns.set()

ret= us_dir1_load_csv(dir0 = 'symbol', dir1 = 'fh', filename='fh_index_price_ratio.csv')

metrics = qs.reports.metrics(ret, mode='basic', display = False, as_pct = True)

metrics = metrics.T.sort_values(by='Sharpe', axis=0, ascending=False).T

metrics.columns = metrics.columns.str.replace('_', ' ')

us_dir1_store_csv(dir0 = 'symbol', dir1 = 'fh', filename='fh_index_analysis' + '.csv', data = metrics, encoding='utf-8-sig')

display(metrics)
# Display DataFrame in a scrollable box
# output = widgets.Output()
# with output:
#     display(metrics)
    
# scrollable = widgets.VBox([output])
# display(scrollable)
# Out:
#                       Semiconductors & Semiconductor Equipment    Software  \
# Start Period                                        2018-01-02  2018-01-02
# End Period                                          2024-08-29  2024-08-29
# Risk-Free Rate                                               0           0
# Time in Market                                           100.0       100.0
# Total Return                                              387%        262%
# CAGR% (Annual Return)                                    26.85       21.31
# Sharpe                                                    1.03        1.01
# RoMaD                                                     0.55         0.5
# Prob. Sharpe Ratio                                       98.62       98.46
# Sortino                                                   1.51        1.45
# Sortino/√2                                                1.06        1.02
# Omega                                                     1.07        1.07
# Max Drawdown                                            -49.16      -42.33
# Longest DD Days                                            581         792
# MTD                                                      -1.89        0.22
# 3M                                                       -1.24        0.98
# 6M                                                       22.61        1.87
# YTD                                                      52.41        8.75
# 1Y                                                       77.53       24.88
# 3Y (ann.)                                                28.76        7.36
# 5Y (ann.)                                                36.69       20.12
# 10Y (ann.)                                               26.85       21.31
# All-time (ann.)                                          26.85       21.31
# Avg. Drawdown                                            -4.89       -3.41
# Avg. Drawdown Days                                          28          24
# Recovery Factor                                           4.05        3.63
# Ulcer Index                                               0.16        0.15
# Serenity Index                                            0.92        0.62
#
#                       Electronic Equipment, Instruments & Components  \
# Start Period                                              2018-01-02
# End Period                                                2024-08-29
# Risk-Free Rate                                                     0
# Time in Market                                                 100.0
# Total Return                                                    254%
# CAGR% (Annual Return)                                          20.88
# Sharpe                                                          0.96
# RoMaD                                                           0.58
# Prob. Sharpe Ratio                                             97.99
# Sortino                                                         1.39
# Sortino/√2                                                      0.98
# Omega                                                           1.07
# Max Drawdown                                                  -36.23
# Longest DD Days                                                  542
# MTD                                                             3.29
# 3M                                                             17.74
# 6M                                                             22.89
# YTD                                                            16.38
# 1Y                                                             23.76
# 3Y (ann.)                                                       13.8
# 5Y (ann.)                                                      26.71
# 10Y (ann.)                                                     20.88
# All-time (ann.)                                                20.88
# Avg. Drawdown                                                  -5.38
# Avg. Drawdown Days                                                39
# Recovery Factor                                                 4.26
# Ulcer Index                                                     0.13
# Serenity Index                                                  0.97
#
#                       Transportation Infrastructure Biotechnology  \
# Start Period                             2018-01-02    2018-01-02
# End Period                               2024-08-29    2024-08-29
# Risk-Free Rate                                    0             0
# Time in Market                                100.0         100.0
# Total Return                                   139%          151%
# CAGR% (Annual Return)                         13.97         14.81
# Sharpe                                         0.93          0.87
# RoMaD                                          0.46          0.45
# Prob. Sharpe Ratio                            97.58         96.84
# Sortino                                        1.32          1.25
# Sortino/√2                                     0.93          0.88
# Omega                                          1.07          1.07
# Max Drawdown                                 -30.43        -33.09
# Longest DD Days                                 586           946
# MTD                                            0.89          2.41
# 3M                                             7.83          7.02
# 6M                                             1.63          9.01
# YTD                                           13.09         17.47
# 1Y                                            21.36         22.25
# 3Y (ann.)                                     11.82          7.12
# 5Y (ann.)                                     15.61         17.62
# 10Y (ann.)                                    13.97         14.81
# All-time (ann.)                               13.97         14.81
# Avg. Drawdown                                 -2.79         -3.29
# Avg. Drawdown Days                               31            30
# Recovery Factor                                3.27           3.3
# Ulcer Index                                    0.07          0.13
# Serenity Index                                 1.31          0.51
#
#                       Trading Companies & Distributors Professional Services  \
# Start Period                                2018-01-02            2018-01-02
# End Period                                  2024-08-29            2024-08-29
# Risk-Free Rate                                       0                     0
# Time in Market                                   100.0                 100.0
# Total Return                                      159%                  127%
# CAGR% (Annual Return)                            15.36                 13.07
# Sharpe                                            0.84                  0.81
# RoMaD                                             0.44                  0.32
# Prob. Sharpe Ratio                               96.35                 95.66
# Sortino                                           1.23                  1.14
# Sortino/√2                                        0.87                  0.81
# Omega                                             1.07                  1.07
# Max Drawdown                                     -34.9                -40.25
# Longest DD Days                                    496                   751
# MTD                                              -3.74                  3.41
# 3M                                                0.59                  8.62
# 6M                                               -0.72                  7.51
# YTD                                               7.52                 12.79
# 1Y                                               22.65                 18.62
# 3Y (ann.)                                        18.54                  7.23
# 5Y (ann.)                                        20.67                 11.88
# 10Y (ann.)                                       15.36                 13.07
# All-time (ann.)                                  15.36                 13.07
# Avg. Drawdown                                    -3.64                 -2.21
# Avg. Drawdown Days                                  34                    21
# Recovery Factor                                   3.33                  2.43
# Ulcer Index                                       0.09                   0.1
# Serenity Index                                    1.17                  0.76
#
#                       Construction & Engineering  \
# Start Period                          2018-01-02
# End Period                            2024-08-29
# Risk-Free Rate                                 0
# Time in Market                             100.0
# Total Return                                152%
# CAGR% (Annual Return)                      14.86
# Sharpe                                      0.77
# RoMaD                                       0.29
# Prob. Sharpe Ratio                         94.76
# Sortino                                     1.08
# Sortino/√2                                  0.77
# Omega                                       1.07
# Max Drawdown                              -50.61
# Longest DD Days                              671
# MTD                                         0.92
# 3M                                          9.57
# 6M                                         17.69
# YTD                                        22.18
# 1Y                                         39.08
# 3Y (ann.)                                  18.49
# 5Y (ann.)                                  20.42
# 10Y (ann.)                                 14.86
# All-time (ann.)                            14.86
# Avg. Drawdown                               -5.1
# Avg. Drawdown Days                            40
# Recovery Factor                             2.34
# Ulcer Index                                 0.13
# Serenity Index                              0.64
#
#                       Diversified Telecommunication Services  \
# Start Period                                      2018-01-02
# End Period                                        2024-08-29
# Risk-Free Rate                                             0
# Time in Market                                         100.0
# Total Return                                            139%
# CAGR% (Annual Return)                                  13.98
# Sharpe                                                  0.77
# RoMaD                                                   0.38
# Prob. Sharpe Ratio                                     95.13
# Sortino                                                 1.12
# Sortino/√2                                              0.79
# Omega                                                   1.07
# Max Drawdown                                          -37.21
# Longest DD Days                                          769
# MTD                                                     -1.7
# 3M                                                     -3.39
# 6M                                                     12.35
# YTD                                                    17.04
# 1Y                                                     27.47
# 3Y (ann.)                                               8.52
# 5Y (ann.)                                              17.83
# 10Y (ann.)                                             13.98
# All-time (ann.)                                        13.98
# Avg. Drawdown                                          -3.27
# Avg. Drawdown Days                                        29
# Recovery Factor                                         2.92
# Ulcer Index                                             0.11
# Serenity Index                                          0.72
#
#                       Health Care Providers & Services Pharmaceuticals  \
# Start Period                                2018-01-02      2018-01-02
# End Period                                  2024-08-29      2024-08-29
# Risk-Free Rate                                       0               0
# Time in Market                                   100.0           100.0
# Total Return                                      127%             82%
# CAGR% (Annual Return)                            13.13            9.42
# Sharpe                                            0.75            0.73
# RoMaD                                             0.38            0.39
# Prob. Sharpe Ratio                               94.65           94.13
# Sortino                                           1.11            1.07
# Sortino/√2                                        0.78            0.75
# Omega                                             1.07            1.07
# Max Drawdown                                    -34.23          -24.16
# Longest DD Days                                    669             681
# MTD                                               1.59             7.6
# 3M                                               11.94           12.64
# 6M                                                6.66           11.77
# YTD                                               4.79           21.45
# 1Y                                               11.79           18.61
# 3Y (ann.)                                          7.0           12.84
# 5Y (ann.)                                        15.38           13.06
# 10Y (ann.)                                       13.13            9.42
# All-time (ann.)                                  13.13            9.42
# Avg. Drawdown                                     -4.6           -3.15
# Avg. Drawdown Days                                  40              42
# Recovery Factor                                    3.0             2.9
# Ulcer Index                                       0.09            0.06
# Serenity Index                                    0.99            1.03
#
#                       Household Products Commercial Services & Supplies  \
# Start Period                  2018-01-02                     2018-01-02
# End Period                    2024-08-29                     2024-08-29
# Risk-Free Rate                         0                              0
# Time in Market                     100.0                          100.0
# Total Return                         86%                           119%
# CAGR% (Annual Return)               9.75                          12.49
# Sharpe                              0.72                           0.64
# RoMaD                               0.44                           0.23
# Prob. Sharpe Ratio                 94.03                          91.45
# Sortino                             1.05                           0.92
# Sortino/√2                          0.74                           0.65
# Omega                               1.07                           1.07
# Max Drawdown                      -22.31                         -54.35
# Longest DD Days                     1161                           1030
# MTD                                 5.97                          -1.03
# 3M                                   7.7                           8.06
# 6M                                 12.51                          10.94
# YTD                                21.78                          16.33
# 1Y                                 24.47                          33.98
# 3Y (ann.)                           6.96                          12.26
# 5Y (ann.)                           8.67                          21.35
# 10Y (ann.)                          9.75                          12.49
# All-time (ann.)                     9.75                          12.49
# Avg. Drawdown                      -2.31                          -6.04
# Avg. Drawdown Days                    43                             68
# Recovery Factor                     3.28                           2.06
# Ulcer Index                         0.09                           0.19
# Serenity Index                      0.58                           0.36
#
#                            Marine Capital Markets Consumer Finance  \
# Start Period           2018-01-02      2018-01-02       2018-01-02
# End Period             2024-08-29      2024-08-29       2024-08-29
# Risk-Free Rate                  0               0                0
# Time in Market              100.0           100.0            100.0
# Total Return                 122%             91%              89%
# CAGR% (Annual Return)        12.7            10.2            10.05
# Sharpe                       0.64            0.63              0.6
# RoMaD                        0.24            0.24             0.25
# Prob. Sharpe Ratio          91.42           90.98            89.96
# Sortino                       0.9            0.88             0.85
# Sortino/√2                   0.63            0.63              0.6
# Omega                        1.07            1.07             1.07
# Max Drawdown               -53.63          -41.82           -40.41
# Longest DD Days               974             913             1130
# MTD                         -2.58            0.86             3.13
# 3M                          -8.16            6.96             5.64
# 6M                          14.78           11.91             1.81
# YTD                         25.56            14.2            12.01
# 1Y                          38.92           29.39            19.19
# 3Y (ann.)                   11.64            4.33            -1.28
# 5Y (ann.)                   17.16           14.24             6.96
# 10Y (ann.)                   12.7            10.2            10.05
# All-time (ann.)              12.7            10.2            10.05
# Avg. Drawdown               -5.35           -3.77            -4.24
# Avg. Drawdown Days             57              44               41
# Recovery Factor              2.13            2.02             2.15
# Ulcer Index                   0.2            0.14             0.18
# Serenity Index               0.32            0.37             0.25
#
#                       Interactive Media & Services  \
# Start Period                            2018-01-02
# End Period                              2024-08-29
# Risk-Free Rate                                   0
# Time in Market                               100.0
# Total Return                                  121%
# CAGR% (Annual Return)                        12.64
# Sharpe                                         0.6
# RoMaD                                         0.16
# Prob. Sharpe Ratio                           89.91
# Sortino                                       0.86
# Sortino/√2                                    0.61
# Omega                                         1.07
# Max Drawdown                                -78.16
# Longest DD Days                               1045
# MTD                                           8.29
# 3M                                           11.87
# 6M                                           30.21
# YTD                                          40.03
# 1Y                                           56.68
# 3Y (ann.)                                   -27.18
# 5Y (ann.)                                    15.31
# 10Y (ann.)                                   12.64
# All-time (ann.)                              12.64
# Avg. Drawdown                                -6.83
# Avg. Drawdown Days                              40
# Recovery Factor                               1.74
# Ulcer Index                                   0.46
# Serenity Index                                0.09
#
#                       Real Estate Management & Development  \
# Start Period                                    2018-01-02
# End Period                                      2024-08-29
# Risk-Free Rate                                           0
# Time in Market                                       100.0
# Total Return                                           99%
# CAGR% (Annual Return)                                10.87
# Sharpe                                                0.59
# RoMaD                                                 0.22
# Prob. Sharpe Ratio                                   90.22
# Sortino                                               0.91
# Sortino/√2                                            0.64
# Omega                                                 1.07
# Max Drawdown                                        -49.22
# Longest DD Days                                       1295
# MTD                                                  -0.02
# 3M                                                    3.67
# 6M                                                   -0.41
# YTD                                                  -5.54
# 1Y                                                    2.54
# 3Y (ann.)                                            -7.83
# 5Y (ann.)                                             9.11
# 10Y (ann.)                                           10.87
# All-time (ann.)                                      10.87
# Avg. Drawdown                                        -4.26
# Avg. Drawdown Days                                      45
# Recovery Factor                                        2.0
# Ulcer Index                                           0.25
# Serenity Index                                        0.17
#
#                       Health Care Equipment & Supplies Multi-Utilities  \
# Start Period                                2018-01-02      2018-01-02
# End Period                                  2024-08-29      2024-08-29
# Risk-Free Rate                                       0               0
# Time in Market                                   100.0           100.0
# Total Return                                       88%             86%
# CAGR% (Annual Return)                             9.93            9.81
# Sharpe                                            0.58            0.57
# RoMaD                                             0.19            0.24
# Prob. Sharpe Ratio                               89.71           90.86
# Sortino                                           0.85            0.94
# Sortino/√2                                         0.6            0.67
# Omega                                             1.07            1.07
# Max Drawdown                                    -50.92          -41.28
# Longest DD Days                                   1061             862
# MTD                                               6.39            0.39
# 3M                                               14.54            4.44
# 6M                                               15.12            15.2
# YTD                                              22.79            9.69
# 1Y                                               21.48            9.86
# 3Y (ann.)                                         0.54            0.01
# 5Y (ann.)                                         9.35            0.82
# 10Y (ann.)                                        9.93            9.81
# All-time (ann.)                                   9.93            9.81
# Avg. Drawdown                                     -3.4           -3.42
# Avg. Drawdown Days                                  37              45
# Recovery Factor                                   1.73            2.06
# Ulcer Index                                       0.26            0.13
# Serenity Index                                    0.12            0.46
#
#                       Automobiles IT Services Paper & Forest Products  \
# Start Period           2018-01-02  2018-01-02              2018-01-02
# End Period             2024-08-29  2024-08-29              2024-08-29
# Risk-Free Rate                  0           0                       0
# Time in Market              100.0       100.0                   100.0
# Total Return                 145%         67%                     90%
# CAGR% (Annual Return)       14.43        7.97                   10.09
# Sharpe                       0.57        0.56                    0.56
# RoMaD                        0.19        0.22                    0.24
# Prob. Sharpe Ratio          93.83        88.5                    88.2
# Sortino                      1.13        0.79                    0.78
# Sortino/√2                    0.8        0.56                    0.55
# Omega                        1.07        1.07                    1.07
# Max Drawdown               -76.53      -36.73                   -42.8
# Longest DD Days               744         974                     848
# MTD                         -5.33        2.43                  -10.37
# 3M                           6.83       12.93                   -4.36
# 6M                          -2.95       -0.09                   -0.06
# YTD                         -7.23        6.21                   -4.51
# 1Y                          -2.81       15.56                    7.97
# 3Y (ann.)                   -3.35         0.5                    7.46
# 5Y (ann.)                   22.58        7.45                    15.7
# 10Y (ann.)                  14.43        7.97                   10.09
# All-time (ann.)             14.43        7.97                   10.09
# Avg. Drawdown              -10.03       -3.38                   -6.86
# Avg. Drawdown Days             80          40                      62
# Recovery Factor              2.67         1.8                    2.29
# Ulcer Index                  0.37        0.15                    0.18
# Serenity Index               0.33        0.23                    0.34
#
#                       Specialty Retail  \
# Start Period                2018-01-02
# End Period                  2024-08-29
# Risk-Free Rate                       0
# Time in Market                   100.0
# Total Return                       73%
# CAGR% (Annual Return)             8.57
# Sharpe                            0.55
# RoMaD                             0.18
# Prob. Sharpe Ratio               87.69
# Sortino                           0.76
# Sortino/√2                        0.53
# Omega                             1.07
# Max Drawdown                    -47.38
# Longest DD Days                    848
# MTD                               -0.1
# 3M                                 6.6
# 6M                                0.73
# YTD                              10.41
# 1Y                               17.29
# 3Y (ann.)                         1.49
# 5Y (ann.)                        11.67
# 10Y (ann.)                        8.57
# All-time (ann.)                   8.57
# Avg. Drawdown                    -4.34
# Avg. Drawdown Days                  53
# Recovery Factor                    1.6
# Ulcer Index                       0.13
# Serenity Index                    0.38
#
#                       Technology Hardware, Storage & Peripherals  \
# Start Period                                          2018-01-02
# End Period                                            2024-08-29
# Risk-Free Rate                                                 0
# Time in Market                                             100.0
# Total Return                                                 89%
# CAGR% (Annual Return)                                      10.02
# Sharpe                                                      0.55
# RoMaD                                                       0.22
# Prob. Sharpe Ratio                                         87.76
# Sortino                                                     0.76
# Sortino/√2                                                  0.54
# Omega                                                       1.07
# Max Drawdown                                               -45.0
# Longest DD Days                                              933
# MTD                                                         -8.9
# 3M                                                        -15.79
# 6M                                                          3.56
# YTD                                                        17.09
# 1Y                                                         26.87
# 3Y (ann.)                                                   4.77
# 5Y (ann.)                                                  15.29
# 10Y (ann.)                                                 10.02
# All-time (ann.)                                            10.02
# Avg. Drawdown                                              -8.34
# Avg. Drawdown Days                                            97
# Recovery Factor                                             2.25
# Ulcer Index                                                 0.18
# Serenity Index                                              0.41
#
#                       Internet & Direct Marketing Retail Electric Utilities  \
# Start Period                                  2018-01-02         2018-01-02
# End Period                                    2024-08-29         2024-08-29
# Risk-Free Rate                                         0                  0
# Time in Market                                     100.0              100.0
# Total Return                                         87%                63%
# CAGR% (Annual Return)                               9.88                7.6
# Sharpe                                              0.55               0.54
# RoMaD                                               0.17               0.21
# Prob. Sharpe Ratio                                 88.01              87.86
# Sortino                                             0.78               0.78
# Sortino/√2                                          0.55               0.55
# Omega                                               1.07               1.07
# Max Drawdown                                      -58.37             -36.64
# Longest DD Days                                     1416                739
# MTD                                                -5.79               4.29
# 3M                                                 -3.42              11.83
# 6M                                                  2.05              23.55
# YTD                                                13.45              19.73
# 1Y                                                 24.31              21.14
# 3Y (ann.)                                          -3.51               6.36
# 5Y (ann.)                                           9.45               5.55
# 10Y (ann.)                                          9.88                7.6
# All-time (ann.)                                     9.88                7.6
# Avg. Drawdown                                      -6.49              -3.64
# Avg. Drawdown Days                                    63                 43
# Recovery Factor                                     1.65               1.74
# Ulcer Index                                         0.25               0.11
# Serenity Index                                      0.16               0.41
#
#                       Electrical Equipment Water Utilities Distributors  \
# Start Period                    2018-01-02      2018-01-02   2018-01-02
# End Period                      2024-08-29      2024-08-29   2024-08-29
# Risk-Free Rate                           0               0            0
# Time in Market                       100.0           100.0        100.0
# Total Return                           83%             65%          61%
# CAGR% (Annual Return)                 9.53            7.77         7.44
# Sharpe                                0.53            0.52         0.52
# RoMaD                                 0.21            0.22         0.18
# Prob. Sharpe Ratio                   87.13           86.78        86.81
# Sortino                               0.76            0.74         0.75
# Sortino/√2                            0.54            0.53         0.53
# Omega                                 1.07            1.07         1.07
# Max Drawdown                         -44.5          -35.01       -40.73
# Longest DD Days                       1297             970          985
# MTD                                  -3.85            1.17        -1.69
# 3M                                    -5.0           13.49         3.13
# 6M                                     2.7           15.58         5.76
# YTD                                  10.06            6.37        10.19
# 1Y                                    5.98            6.76        19.91
# 3Y (ann.)                             3.53            2.47         8.78
# 5Y (ann.)                            16.03            4.33        12.86
# 10Y (ann.)                            9.53            7.77         7.44
# All-time (ann.)                       9.53            7.77         7.44
# Avg. Drawdown                        -9.48           -4.22        -3.75
# Avg. Drawdown Days                     170              62           59
# Recovery Factor                       2.21            1.97         1.58
# Ulcer Index                           0.21            0.11         0.11
# Serenity Index                         0.3            0.48         0.41
#
#                       Building Products  \
# Start Period                 2018-01-02
# End Period                   2024-08-29
# Risk-Free Rate                        0
# Time in Market                    100.0
# Total Return                        73%
# CAGR% (Annual Return)              8.57
# Sharpe                             0.52
# RoMaD                              0.17
# Prob. Sharpe Ratio                86.66
# Sortino                            0.73
# Sortino/√2                         0.52
# Omega                              1.07
# Max Drawdown                      -49.0
# Longest DD Days                     989
# MTD                               -4.55
# 3M                                 2.75
# 6M                                 2.07
# YTD                                 8.4
# 1Y                                23.14
# 3Y (ann.)                          8.65
# 5Y (ann.)                         14.56
# 10Y (ann.)                         8.57
# All-time (ann.)                    8.57
# Avg. Drawdown                     -5.19
# Avg. Drawdown Days                   59
# Recovery Factor                    1.67
# Ulcer Index                        0.16
# Serenity Index                     0.33
#
#                       Independent Power and Renewable Electricity Producers  \
# Start Period                                                  2018-01-02
# End Period                                                    2024-08-29
# Risk-Free Rate                                                         0
# Time in Market                                                     100.0
# Total Return                                                         65%
# CAGR% (Annual Return)                                               7.79
# Sharpe                                                              0.51
# RoMaD                                                               0.18
# Prob. Sharpe Ratio                                                 86.07
# Sortino                                                              0.7
# Sortino/√2                                                           0.5
# Omega                                                               1.07
# Max Drawdown                                                      -43.05
# Longest DD Days                                                     1176
# MTD                                                                 4.65
# 3M                                                                -12.25
# 6M                                                                 36.69
# YTD                                                                 39.3
# 1Y                                                                 48.66
# 3Y (ann.)                                                           9.25
# 5Y (ann.)                                                           7.82
# 10Y (ann.)                                                          7.79
# All-time (ann.)                                                     7.79
# Avg. Drawdown                                                      -5.94
# Avg. Drawdown Days                                                    80
# Recovery Factor                                                     1.66
# Ulcer Index                                                         0.16
# Serenity Index                                                      0.24
#
#                         Insurance Health Care Technology   Machinery  \
# Start Period           2018-01-02             2018-01-02  2018-01-02
# End Period             2024-08-29             2024-08-29  2024-08-29
# Risk-Free Rate                  0                      0           0
# Time in Market              100.0                  100.0       100.0
# Total Return                  56%                    55%         56%
# CAGR% (Annual Return)        6.95                   6.75         6.9
# Sharpe                        0.5                   0.49        0.48
# RoMaD                        0.16                   0.17        0.15
# Prob. Sharpe Ratio          85.47                   85.0       84.58
# Sortino                      0.68                   0.68        0.67
# Sortino/√2                   0.48                   0.48        0.47
# Omega                        1.07                   1.07        1.07
# Max Drawdown               -44.41                 -39.89      -46.81
# Longest DD Days               737                   1086        1040
# MTD                          4.62                   7.24       -0.36
# 3M                          11.05                   3.99        1.74
# 6M                          12.67                  -3.22        4.86
# YTD                         23.04                   3.48       11.64
# 1Y                          31.75                    7.2       19.44
# 3Y (ann.)                   11.61                  -7.15         8.3
# 5Y (ann.)                    8.83                   2.79       13.97
# 10Y (ann.)                   6.95                   6.75         6.9
# All-time (ann.)              6.95                   6.75         6.9
# Avg. Drawdown               -4.21                  -3.94       -4.42
# Avg. Drawdown Days             57                     42          68
# Recovery Factor              1.38                   1.51        1.37
# Ulcer Index                  0.11                   0.18        0.15
# Serenity Index               0.36                   0.14        0.24
#
#                       Thrifts & Mortgage Finance Road & Rail  \
# Start Period                          2018-01-02  2018-01-02
# End Period                            2024-08-29  2024-08-29
# Risk-Free Rate                                 0           0
# Time in Market                             100.0       100.0
# Total Return                                 60%         53%
# CAGR% (Annual Return)                       7.34        6.56
# Sharpe                                      0.46        0.45
# RoMaD                                       0.12        0.15
# Prob. Sharpe Ratio                         83.57        83.3
# Sortino                                     0.65        0.65
# Sortino/√2                                  0.46        0.46
# Omega                                       1.07        1.07
# Max Drawdown                               -59.3      -43.31
# Longest DD Days                              977         883
# MTD                                         0.44        0.59
# 3M                                         11.94        4.58
# 6M                                         18.11       -3.23
# YTD                                        16.46        1.81
# 1Y                                          33.0       10.57
# 3Y (ann.)                                   5.54        4.31
# 5Y (ann.)                                   6.22         7.1
# 10Y (ann.)                                  7.34        6.56
# All-time (ann.)                             7.34        6.56
# Avg. Drawdown                              -7.93       -5.41
# Avg. Drawdown Days                            80          68
# Recovery Factor                              1.4         1.5
# Ulcer Index                                 0.18        0.15
# Serenity Index                              0.29        0.27
#
#                       Household Durables Metals & Mining   Chemicals  \
# Start Period                  2018-01-02      2018-01-02  2018-01-02
# End Period                    2024-08-29      2024-08-29  2024-08-29
# Risk-Free Rate                         0               0           0
# Time in Market                     100.0           100.0       100.0
# Total Return                         52%             56%         47%
# CAGR% (Annual Return)               6.52            6.92        5.98
# Sharpe                              0.45            0.45        0.42
# RoMaD                               0.15            0.15        0.14
# Prob. Sharpe Ratio                  82.7            83.4       81.63
# Sortino                             0.61            0.64        0.62
# Sortino/√2                          0.43            0.45        0.44
# Omega                               1.07            1.07        1.07
# Max Drawdown                      -43.07          -46.06      -42.92
# Longest DD Days                      991             790        1247
# MTD                                -0.21           -2.02        0.88
# 3M                                 10.99           -6.72        1.48
# 6M                                 -1.99            9.91        5.24
# YTD                                 5.88           -1.51        2.82
# 1Y                                 11.31            10.7        7.66
# 3Y (ann.)                          -0.63            8.34       -0.65
# 5Y (ann.)                           7.84           12.66        4.64
# 10Y (ann.)                          6.52            6.92        5.98
# All-time (ann.)                     6.52            6.92        5.98
# Avg. Drawdown                      -5.83           -8.54       -7.92
# Avg. Drawdown Days                    70              98         112
# Recovery Factor                     1.56            1.57        1.51
# Ulcer Index                         0.19            0.16        0.18
# Serenity Index                      0.18            0.29         0.2
#
#                       Textiles, Apparel & Luxury Goods  \
# Start Period                                2018-01-02
# End Period                                  2024-08-29
# Risk-Free Rate                                       0
# Time in Market                                   100.0
# Total Return                                       40%
# CAGR% (Annual Return)                             5.13
# Sharpe                                            0.38
# RoMaD                                             0.11
# Prob. Sharpe Ratio                               79.41
# Sortino                                           0.54
# Sortino/√2                                        0.38
# Omega                                             1.07
# Max Drawdown                                    -46.89
# Longest DD Days                                   1026
# MTD                                               4.57
# 3M                                                0.96
# 6M                                               -7.12
# YTD                                              -4.27
# 1Y                                                 8.7
# 3Y (ann.)                                        -6.25
# 5Y (ann.)                                         2.93
# 10Y (ann.)                                        5.13
# All-time (ann.)                                   5.13
# Avg. Drawdown                                    -4.58
# Avg. Drawdown Days                                  51
# Recovery Factor                                   1.28
# Ulcer Index                                       0.22
# Serenity Index                                    0.13
#
#                       Hotels, Restaurants & Leisure  \
# Start Period                             2018-01-02
# End Period                               2024-08-29
# Risk-Free Rate                                    0
# Time in Market                                100.0
# Total Return                                    32%
# CAGR% (Annual Return)                          4.32
# Sharpe                                         0.36
# RoMaD                                          0.09
# Prob. Sharpe Ratio                            77.68
# Sortino                                         0.5
# Sortino/√2                                     0.35
# Omega                                          1.07
# Max Drawdown                                 -49.23
# Longest DD Days                                 863
# MTD                                            4.12
# 3M                                              4.3
# 6M                                            -0.15
# YTD                                            1.99
# 1Y                                             7.99
# 3Y (ann.)                                      1.23
# 5Y (ann.)                                      5.58
# 10Y (ann.)                                     4.32
# All-time (ann.)                                4.32
# Avg. Drawdown                                 -7.21
# Avg. Drawdown Days                              107
# Recovery Factor                                0.97
# Ulcer Index                                    0.13
# Serenity Index                                 0.25
#
#                       Oil, Gas & Consumable Fuels Aerospace & Defense  \
# Start Period                           2018-01-02          2018-01-02
# End Period                             2024-08-29          2024-08-29
# Risk-Free Rate                                  0                   0
# Time in Market                              100.0               100.0
# Total Return                                  31%                 31%
# CAGR% (Annual Return)                         4.1                4.16
# Sharpe                                       0.35                0.34
# RoMaD                                        0.06                0.08
# Prob. Sharpe Ratio                          76.83               77.28
# Sortino                                      0.47                0.51
# Sortino/√2                                   0.34                0.36
# Omega                                        1.07                1.07
# Max Drawdown                               -64.42              -51.75
# Longest DD Days                              1216                1546
# MTD                                         -1.21                1.91
# 3M                                           1.32                9.59
# 6M                                           8.84                9.44
# YTD                                         10.05                4.73
# 1Y                                           7.45               14.62
# 3Y (ann.)                                   14.77                9.15
# 5Y (ann.)                                    7.35                1.52
# 10Y (ann.)                                    4.1                4.16
# All-time (ann.)                               4.1                4.16
# Avg. Drawdown                                -6.4                -7.8
# Avg. Drawdown Days                             98                 124
# Recovery Factor                              0.91                 1.2
# Ulcer Index                                  0.22                0.17
# Serenity Index                               0.13                0.25
#
#                       Communications Equipment Energy Equipment & Services  \
# Start Period                        2018-01-02                  2018-01-02
# End Period                          2024-08-29                  2024-08-29
# Risk-Free Rate                               0                           0
# Time in Market                           100.0                       100.0
# Total Return                               26%                         14%
# CAGR% (Annual Return)                     3.49                        2.01
# Sharpe                                    0.32                        0.32
# RoMaD                                     0.09                        0.02
# Prob. Sharpe Ratio                       75.09                       76.01
# Sortino                                   0.44                         0.5
# Sortino/√2                                0.31                        0.35
# Omega                                     1.07                        1.07
# Max Drawdown                            -40.36                      -84.69
# Longest DD Days                            974                        1995
# MTD                                       4.59                       -3.55
# 3M                                        11.8                        0.02
# 6M                                       14.51                        1.41
# YTD                                      11.26                        1.87
# 1Y                                        6.77                        0.42
# 3Y (ann.)                                 -2.3                       37.59
# 5Y (ann.)                                 2.56                       17.18
# 10Y (ann.)                                3.49                        2.01
# All-time (ann.)                           3.49                        2.01
# Avg. Drawdown                            -4.24                       -8.32
# Avg. Drawdown Days                          63                         159
# Recovery Factor                           1.05                        0.98
# Ulcer Index                               0.19                        0.46
# Serenity Index                             0.1                        0.07
#
#                             Media Construction Materials  \
# Start Period           2018-01-02             2018-01-02
# End Period             2024-08-29             2024-08-29
# Risk-Free Rate                  0                      0
# Time in Market              100.0                  100.0
# Total Return                  26%                    23%
# CAGR% (Annual Return)        3.58                    3.1
# Sharpe                       0.32                    0.3
# RoMaD                        0.06                   0.06
# Prob. Sharpe Ratio          75.35                  73.84
# Sortino                      0.46                   0.42
# Sortino/√2                   0.32                   0.29
# Omega                        1.07                   1.07
# Max Drawdown               -63.28                 -50.61
# Longest DD Days              1026                   1040
# MTD                          4.19                  -6.39
# 3M                          10.14                  -5.32
# 6M                           7.13                  -5.29
# YTD                          8.03                  -0.75
# 1Y                          25.06                  -0.15
# 3Y (ann.)                  -19.61                  -1.47
# 5Y (ann.)                    0.33                    6.1
# 10Y (ann.)                   3.58                    3.1
# All-time (ann.)              3.58                    3.1
# Avg. Drawdown               -4.53                  -7.72
# Avg. Drawdown Days             37                    112
# Recovery Factor              0.73                   0.87
# Ulcer Index                  0.33                   0.18
# Serenity Index               0.04                   0.13
#
#                       Air Freight & Logistics   Beverages       Banks  \
# Start Period                       2018-01-02  2018-01-02  2018-01-02
# End Period                         2024-08-29  2024-08-29  2024-08-29
# Risk-Free Rate                              0           0           0
# Time in Market                          100.0       100.0       100.0
# Total Return                              16%         15%         10%
# CAGR% (Annual Return)                    2.24        2.16        1.45
# Sharpe                                   0.26        0.25        0.22
# RoMaD                                    0.05        0.06        0.03
# Prob. Sharpe Ratio                      71.12        70.4       68.35
# Sortino                                  0.37        0.35        0.31
# Sortino/√2                               0.26        0.25        0.22
# Omega                                    1.07        1.07        1.07
# Max Drawdown                           -41.96      -38.82      -53.78
# Longest DD Days                          1185         995        1439
# MTD                                     -0.14        1.54         0.8
# 3M                                       1.04        0.09        7.98
# 6M                                      -0.02       -1.03       16.62
# YTD                                     -5.15       -0.84       15.63
# 1Y                                      -7.34       -1.27       31.17
# 3Y (ann.)                               -3.75        4.53         3.5
# 5Y (ann.)                                6.45        1.51        4.73
# 10Y (ann.)                               2.24        2.16        1.45
# All-time (ann.)                          2.24        2.16        1.45
# Avg. Drawdown                           -6.56       -5.44      -15.68
# Avg. Drawdown Days                         98         112         400
# Recovery Factor                          0.91        0.66        0.59
# Ulcer Index                              0.19        0.11        0.21
# Serenity Index                           0.11        0.13        0.07
#
#                       Entertainment    Airlines Auto Components  \
# Start Period             2018-01-02  2018-01-02      2018-01-02
# End Period               2024-08-29  2024-08-29      2024-08-29
# Risk-Free Rate                    0           0               0
# Time in Market                100.0       100.0           100.0
# Total Return                     4%        -35%            -29%
# CAGR% (Annual Return)          0.62       -6.35           -4.99
# Sharpe                         0.18        0.03               0
# RoMaD                          0.01       -0.09           -0.08
# Prob. Sharpe Ratio            64.73       52.83           50.14
# Sortino                        0.24        0.05               0
# Sortino/√2                     0.17        0.03               0
# Omega                          1.07        1.07            1.07
# Max Drawdown                 -56.36      -66.94          -64.88
# Longest DD Days                1087        2167            1180
# MTD                            1.19        0.05           -4.79
# 3M                             2.25      -11.59          -10.58
# 6M                            -0.26      -13.16          -13.53
# YTD                             6.5       -8.33          -15.77
# 1Y                             9.25       -6.18          -17.77
# 3Y (ann.)                    -14.81      -10.02           -12.4
# 5Y (ann.)                     -1.43       -6.13           -0.69
# 10Y (ann.)                     0.62       -6.35           -4.99
# All-time (ann.)                0.62       -6.35           -4.99
# Avg. Drawdown                 -5.51      -18.47          -10.34
# Avg. Drawdown Days               65         483             171
# Recovery Factor                0.42        0.11               0
# Ulcer Index                    0.29        0.32            0.29
# Serenity Index                 0.02        0.01               0
#
#                       Industrial Conglomerates     Tobacco
# Start Period                        2018-01-02  2018-01-02
# End Period                          2024-08-29  2024-08-29
# Risk-Free Rate                               0           0
# Time in Market                           100.0       100.0
# Total Return                              -30%        -19%
# CAGR% (Annual Return)                    -5.27       -3.12
# Sharpe                                   -0.02       -0.04
# RoMaD                                     -0.1       -0.06
# Prob. Sharpe Ratio                       48.18       46.81
# Sortino                                  -0.03       -0.05
# Sortino/√2                               -0.02       -0.04
# Omega                                     1.07        1.07
# Max Drawdown                            -52.97      -54.16
# Longest DD Days                            567        2409
# MTD                                     -13.75        6.67
# 3M                                       -9.45       20.91
# 6M                                      -15.13       30.54
# YTD                                      -9.21        28.6
# 1Y                                      -10.34       21.41
# 3Y (ann.)                                -17.6        3.77
# 5Y (ann.)                                -9.39         5.9
# 10Y (ann.)                               -5.27       -3.12
# All-time (ann.)                          -5.27       -3.12
# Avg. Drawdown                             -7.9      -14.12
# Avg. Drawdown Days                          90         606
# Recovery Factor                           0.07        0.08
# Ulcer Index                               0.23        0.34
# Serenity Index                           -0.01           0

# %%
# %%time

df= us_dir1_load_csv(dir0 = 'symbol', dir1 = 'xq', filename='建筑与工程.csv')
df = df.sort_values(by='market_capital', axis=0, ascending=False)
display(df)

# %%
from dataset.us_equity_load import *
sector_name = '半导体产品与设备'
sector_name = '软件'
# sector_name = '汽车零配件'
# sector_name = '饮料'
# sector_name = '燃气公用事业'
# sector_name = '家庭耐用消费品'
sector_name = '饮料'
sector_name = '家庭耐用消费品'

start_date = '2014-01-29'
end_date = '2024-08-08'

df = us_equity_sector_daily_data_load(sector_name = sector_name, start_date = start_date, end_date = end_date, dir_option = 'xq', trade_option = 'close')

df = pd.DataFrame(df)

metrics = qs.reports.metrics(df, mode='basic', display = False, as_pct = True)

metrics = metrics.T.sort_values(by='CAGR% (Annual Return)', axis=0, ascending=False).T

us_dir1_store_csv(dir0 = 'symbol', dir1 = 'xq', filename='xq_stock_analysis' + sector_name + '.csv', data = metrics, encoding='utf-8-sig')

display(metrics)

# %%
from dataset.us_equity_load import *
sector_name = '半导体产品与设备'
sector_name = '软件'
# sector_name = '汽车零配件'
# sector_name = '饮料'
# sector_name = '燃气公用事业'
# sector_name = '家庭耐用消费品'
sector_name = '饮料'
sector_name = 'Beverages'

start_date = '2014-01-29'
end_date = '2024-08-08'

df = us_equity_sector_daily_data_load(sector_name = sector_name, start_date = start_date, end_date = end_date, dir_option = 'fh', trade_option = 'close')

df = pd.DataFrame(df)

metrics = qs.reports.metrics(df, mode='basic', display = False, as_pct = True)

metrics = metrics.T.sort_values(by='CAGR% (Annual Return)', axis=0, ascending=False).T

us_dir1_store_csv(dir0 = 'symbol', dir1 = 'xq', filename='xq_stock_analysis' + sector_name + '.csv', data = metrics, encoding='utf-8-sig')

display(metrics)
# Out:
# file /home/disk1/quant_free/data/equity/AKO-A/xq/daily.csv not exsist!!
# file /home/disk1/quant_free/data/equity/AKO-B/xq/daily.csv not exsist!!
# file /home/disk1/quant_free/data/equity/BF-A/xq/daily.csv not exsist!!
# file /home/disk1/quant_free/data/equity/BF-B/xq/daily.csv not exsist!!
# lack of some trade date skip CCEP, data row 1517, date_start 2018-11-07 00:00:00, end_start 2024-08-29 00:00:00
# lack of some trade date skip COCO, data row 746, date_start 2021-10-21 00:00:00, end_start 2024-08-29 00:00:00
# lack of some trade date skip KDP, data row 1603, date_start 2018-07-10 00:00:00, end_start 2024-08-29 00:00:00
# lack of some trade date skip NAPA, data row 901, date_start 2021-03-18 00:00:00, end_start 2024-08-29 00:00:00
# lack of some trade date skip REVG, data row 1980, date_start 2017-01-27 00:00:00, end_start 2024-08-29 00:00:00
# file /home/disk1/quant_free/data/equity/STZ-B/xq/daily.csv not exsist!!
# file /home/disk1/quant_free/data/equity/TAP-A/xq/daily.csv not exsist!!
# lack of some trade date skip VWE, data row 823, date_start 2021-06-08 00:00:00, end_start 2024-08-01 00:00:00
# lack of some trade date skip VWEWW, data row 662, date_start 2022-01-19 00:00:00, end_start 2024-08-01 00:00:00
#                              CELH        COKE        PRMW        FIZZ  \
# Start Period           2014-01-29  2014-01-29  2014-01-29  2014-01-29
# End Period             2024-08-07  2024-08-07  2024-08-07  2024-08-07
# Risk-Free Rate                  0           0           0           0
# Time in Market               81.0       100.0        98.0       100.0
# Total Return              34,675%      1,880%        837%        481%
# CAGR% (Annual Return)       74.33       32.78       23.68       18.19
# Sharpe                       1.26        1.15         0.9        0.73
# RoMaD                        1.19        0.63        0.37        0.26
# Prob. Sharpe Ratio          99.99       99.89       99.21       97.79
# Sortino                      2.21         1.7        1.33         1.1
# Sortino/√2                   1.56         1.2        0.94        0.78
# Omega                         1.0         1.0         1.0         1.0
# Max Drawdown               -62.53      -51.71      -64.72      -69.59
# Longest DD Days               904         744        1178        1288
# MTD                        -15.87        9.39       -0.59       -4.92
# 3M                          -49.7       46.18        9.98        7.41
# 6M                         -29.39       43.07       49.41        7.48
# YTD                        -27.73       37.75       46.24       -0.02
# 1Y                         -17.12       84.15        58.6       -6.51
# 3Y (ann.)                   10.89       49.74        9.31        4.49
# 5Y (ann.)                  102.56       34.98       13.09       22.98
# 10Y (ann.)                  68.47       34.03        19.5       20.72
# All-time (ann.)             74.33       32.78       23.68       18.19
# Avg. Drawdown              -12.32       -6.36       -6.89       -7.73
# Avg. Drawdown Days             52          53          61          80
# Recovery Factor             15.19        7.17        4.68        3.81
# Ulcer Index                  0.31        0.22        0.22        0.36
# Serenity Index               3.12         1.0        0.89         0.3
#
#                              MNST         STZ         PEP          KO  \
# Start Period           2014-01-29  2014-01-29  2014-01-29  2014-01-29
# End Period             2024-08-07  2024-08-07  2024-08-07  2024-08-07
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                 347%        245%        190%        152%
# CAGR% (Annual Return)       15.29       12.49       10.64        9.18
# Sharpe                       0.76        0.72        0.78        0.71
# RoMaD                         0.5        0.23        0.37        0.25
# Prob. Sharpe Ratio          98.36       97.28        98.1       96.93
# Sortino                       1.2        1.02        1.11        0.97
# Sortino/√2                   0.85        0.72        0.78        0.69
# Omega                         1.0         1.0         1.0         1.0
# Max Drawdown               -30.42      -53.54      -28.82      -36.99
# Longest DD Days               737         983         451         743
# MTD                         -1.79        -3.0       -0.51        2.58
# 3M                          -6.81       -7.58       -1.52       10.65
# 6M                         -10.31       -3.63        1.78       16.02
# YTD                        -12.29       -0.88        2.72       18.01
# 1Y                          -8.31       -9.96        -4.1       16.38
# 3Y (ann.)                    1.21        5.43        5.87       10.04
# 5Y (ann.)                   12.29        4.56        7.56        7.82
# 10Y (ann.)                  16.45       12.33        9.73        8.94
# All-time (ann.)             15.29       12.49       10.64        9.18
# Avg. Drawdown               -4.75       -3.96       -2.67       -2.98
# Avg. Drawdown Days             43          36          28          44
# Recovery Factor              6.34        2.93        4.31        2.95
# Ulcer Index                  0.11        0.11        0.06        0.08
# Serenity Index               1.59        1.08        2.09        1.06
#
#                               FMX         SAM         TAP         DEO  \
# Start Period           2014-01-29  2014-01-29  2014-01-29  2014-01-29
# End Period             2024-08-07  2024-08-07  2024-08-07  2024-08-07
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0       100.0       100.0
# Total Return                  45%         26%         24%         24%
# CAGR% (Annual Return)        3.62        2.24        2.05        2.04
# Sharpe                       0.32        0.31        0.26        0.24
# RoMaD                        0.08        0.03        0.03        0.05
# Prob. Sharpe Ratio          80.65       79.62       75.48       74.28
# Sortino                      0.46        0.45        0.36        0.34
# Sortino/√2                   0.32        0.32        0.26        0.24
# Omega                         1.0         1.0         1.0         1.0
# Max Drawdown               -45.54      -80.41      -67.73      -42.92
# Longest DD Days              2033        1267        2852        1083
# MTD                         -0.39        -5.4       -1.42       -2.08
# 3M                          -7.26       -1.16       -8.26      -10.93
# 6M                         -19.74      -24.91      -13.68      -17.63
# YTD                        -14.23      -23.29      -13.56      -15.24
# 1Y                           1.83      -24.94       -17.9       -26.3
# 3Y (ann.)                   11.58      -22.73        6.48      -13.34
# 5Y (ann.)                    5.64        -8.2        1.74       -4.71
# 10Y (ann.)                    3.3        1.67       -0.84        2.74
# All-time (ann.)              3.62        2.24        2.05        2.04
# Avg. Drawdown                -5.6       -7.46       -4.42       -3.29
# Avg. Drawdown Days             98          75          75          53
# Recovery Factor              1.63        1.33        0.93        1.04
# Ulcer Index                  0.16        0.46        0.37        0.15
# Serenity Index               0.25        0.07        0.05        0.15
#
#                               KOF         BUD         CCU        ABEV  \
# Start Period           2014-01-29  2014-01-29  2014-01-29  2014-01-29
# End Period             2024-08-07  2024-08-07  2024-08-07  2024-08-07
# Risk-Free Rate                  0           0           0           0
# Time in Market              100.0       100.0        98.0        95.0
# Total Return                  19%        -23%        -27%        -50%
# CAGR% (Annual Return)        1.69       -2.49       -2.95       -6.44
# Sharpe                       0.23        0.05        0.02       -0.03
# RoMaD                        0.03       -0.03       -0.05       -0.09
# Prob. Sharpe Ratio          73.57       55.16       52.59       46.84
# Sortino                      0.33        0.07        0.03       -0.04
# Sortino/√2                   0.23        0.05        0.02       -0.03
# Omega                         1.0         1.0         1.0         1.0
# Max Drawdown               -63.83      -71.27      -62.23      -72.44
# Longest DD Days              3278        2870        1854        2338
# MTD                         -4.87        1.68       -2.82        8.74
# 3M                         -10.56        1.53      -16.84        -8.2
# 6M                         -10.53       -3.67      -10.23      -15.47
# YTD                         -7.35       -4.99      -13.67       -20.0
# 1Y                          10.45        8.68      -30.94      -20.84
# 3Y (ann.)                   20.29        1.65      -14.21       -6.45
# 5Y (ann.)                   12.14       -7.35      -10.42      -10.15
# 10Y (ann.)                   1.07       -3.82       -3.57       -7.25
# All-time (ann.)              1.69       -2.49       -2.95       -6.44
# Avg. Drawdown              -10.94       -5.88       -8.23       -9.89
# Avg. Drawdown Days            292         117         145         253
# Recovery Factor              0.83        0.16        0.09        0.12
# Ulcer Index                  0.37        0.36         0.3        0.43
# Serenity Index               0.04        0.01        0.01       -0.01
#
#                              REED
# Start Period           2014-01-29
# End Period             2024-08-07
# Risk-Free Rate                  0
# Time in Market               93.0
# Total Return                 -82%
# CAGR% (Annual Return)      -15.11
# Sharpe                       0.35
# RoMaD                       -0.15
# Prob. Sharpe Ratio          96.46
# Sortino                      9.78
# Sortino/√2                   6.92
# Omega                         1.0
# Max Drawdown               -99.19
# Longest DD Days              3803
# MTD                         -8.57
# 3M                          -1.54
# 6M                         -34.85
# YTD                         -20.0
# 1Y                         -53.03
# 3Y (ann.)                    25.1
# 5Y (ann.)                    -6.7
# 10Y (ann.)                 -12.83
# All-time (ann.)            -15.11
# Avg. Drawdown              -23.23
# Avg. Drawdown Days            766
# Recovery Factor             46.76
# Ulcer Index                  0.72
# Serenity Index              57.73
