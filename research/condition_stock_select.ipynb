# %% [markdown]
# ## equity price in sector

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline


# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")

from IPython.display import display
# Setting display options to show all rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

import os
import sys
import seaborn as sns
# from pathlib import Path
# _this_dir = Path(__file__).parent.parent
from dataset.us_equity_load import *
from utils.us_equity_utils import *

from dataset.us_equity_xq_factor import *
from dataset.us_equity_load import *
from factor.price import*
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# sector_name = "IT_Services"
# sector_name = "Entertainment"
sector_name = "Semiconductors_Equipment"
# sector_name = "Automobiles"
# sector_name = "Internet_Retail"
# sector_name = "Electronic_Equipment_Instruments_Components"

symbols = us_equity_symbol_load()

# symbols = us_dir0_load_csv(dir0 = 'symbol', filename= sector_name +'.csv')['symbol'].values

print("symbol list len ", len(symbols))
check_factors = ['pe', 'ps', 'market_capital']
rank_factors = ['roe', 'roa', 'gross_profit_revenue', 'profit_revenue', 'revenue_increase_q2q_rate', 'cash_increase_q2q_rate', 'profit_increase_q2q_rate']
factors = check_factors + rank_factors
start_date = '2022-06-01'
end_date = '2024-06-01'

us_analysis_finance = us_equity_xq_factor(symbols, factors,  start_date, end_date)
df_factors = us_analysis_finance.finance_factors_fectch()
# display(df_factors)

# filtered_df = df_factors.groupby(level='symbol').filter(lambda x: (x['revenue_increase_q2q_rate'] > 30).any() and (x['gross_profit_revenue'] > 50).any() and (x['market_capital'] < 100E9).any())
filtered_df = df_factors.groupby(level='symbol').filter(lambda x: (x['revenue_increase_q2q_rate'] > 30).all() and (x['gross_profit_revenue'] > 50).all() and (x['market_capital'] < 200E9).all())
display(filtered_df)
# Out:
# symbol list len  10321
# no finance data skip stock BRK-B
# no finance data skip stock SPY
# no finance data skip stock LTMAY
# no finance data skip stock NOW
# no finance data skip stock RTNTF
# no finance data skip stock EADSY
# no finance data skip stock AIQUY
# no finance data skip stock TOELY
# no finance data skip stock ABBNY
# no finance data skip stock ATLKY
# no finance data skip stock CSLLY
# no finance data skip stock CFRUY
# no finance data skip stock SHECY
# no finance data skip stock GLNCY
# no finance data skip stock ANZGY
# no finance data skip stock GLD
# no finance data skip stock ET
# no finance data skip stock RAASY
# no finance data skip stock BAESY
# no finance data skip stock CRARY
# no finance data skip stock CTA-PA
# no finance data skip stock DNZOY
# no finance data skip stock OLCLY
# no finance data skip stock DKILY
# no finance data skip stock KHC
# no finance data skip stock CODYY
# no finance data skip stock LHX
# no finance data skip stock GBTC
# no finance data skip stock MSCI
# no finance data skip stock WTKWY
# no finance data skip stock DSCSY
# no finance data skip stock PTCAY
# no finance data skip stock PPERY
# no finance data skip stock MRAAY
# no finance data skip stock SVNDY
# no finance data skip stock DIA
# no finance data skip stock ADM
# no finance data skip stock BDORY
# no finance data skip stock MDY
# no finance data skip stock OEZVY
# no finance data skip stock GWLIF
# no finance data skip stock ANYYY
# no finance data skip stock PUBGY
# no finance data skip stock FANUY
# no finance data skip stock NVZMY
# no finance data skip stock TLGPY
# no finance data skip stock GPN
# no finance data skip stock FRFHF
# no finance data skip stock FUJIY
# no finance data skip stock SYM
# no finance data skip stock ATEYY
# no finance data skip stock DIDIY
# no finance data skip stock BF-B
# no finance data skip stock CJPRY
# no finance data skip stock NTDTY
# no finance data skip stock EJPRY
# no finance data skip stock SMPNY
# no finance data skip stock HDELY
# no finance data skip stock LDOS
# no finance data skip stock CBOE
# no finance data skip stock YAHOY
# no finance data skip stock MGDDY
# no finance data skip stock SGSOY
# no finance data skip stock EDPFY
# no finance data skip stock OMVKY
# no finance data skip stock GFI
# no finance data skip stock WLMIY
# no finance data skip stock BOUYY
# no finance data skip stock KKPNY
# no finance data skip stock CNHI
# no finance data skip stock SGIOY
# no finance data skip stock TKHVY
# no finance data skip stock NNGRY
# no finance data skip stock AZPN
# no finance data skip stock JBAXY
# no finance data skip stock KIKOY
# no finance data skip stock SMKUY
# no finance data skip stock PTBRY
# no finance data skip stock VIVHY
# no finance data skip stock RKUNY
# no finance data skip stock JBSAY
# no finance data skip stock DSEEY
# no finance data skip stock SSMXY
# no finance data skip stock KAIKY
# no finance data skip stock EMRAF
# no finance data skip stock OUKPY
# no finance data skip stock ATR
# no finance data skip stock IDKOY
# no finance data skip stock VDMCY
# no finance data skip stock RDEIY
# no finance data skip stock MOS
# no finance data skip stock BDNNY
# no finance data skip stock CSXXY
# no finance data skip stock GNRC
# no finance data skip stock MTZ
# no finance data skip stock MTLHY
# no finance data skip stock RGLD
# no finance data skip stock ASXFY
# no finance data skip stock EGFEY
# no finance data skip stock EBCOY
# no finance data skip stock MNSO
# no finance data skip stock OSK
# no finance data skip stock JCYGY
# no finance data skip stock HNGKY
# no finance data skip stock HRB
# no finance data skip stock BZZUY
# no finance data skip stock ALSMY
# no finance data skip stock OMRNY
# no finance data skip stock PHYS
# no finance data skip stock BKGFY
# no finance data skip stock BCUCY
# no finance data skip stock UELMO
# no finance data skip stock CMS-PB
# no finance data skip stock AGLY
# no finance data skip stock DUFRY
# no finance data skip stock MEJHY
# no finance data skip stock NGKSY
# no finance data skip stock YKLTY
# no finance data skip stock BECN
# no finance data skip stock CUYTY
# no finance data skip stock CIGI
# no finance data skip stock JSCPY
# no finance data skip stock ZWS
# no finance data skip stock CWST
# no finance data skip stock LKNCY
# no finance data skip stock MOG-A
# no finance data skip stock PDI
# no finance data skip stock TDW
# no finance data skip stock CPG
# no finance data skip stock MGY
# no finance data skip stock ASMVY
# no finance data skip stock ROHCY
# no finance data skip stock PUTKY
# no finance data skip stock NTCOY
# no finance data skip stock PSLV
# no finance data skip stock CEF
# no finance data skip stock VIAAY
# no finance data skip stock DY
# no finance data skip stock GNNDY
# no finance data skip stock SHWDY
# no finance data skip stock PRGO
# no finance data skip stock CURLF
# no finance data skip stock SLVYY
# no finance data skip stock FAURY
# no finance data skip stock IHICY
# no finance data skip stock DXC
# no finance data skip stock ROYMY
# no finance data skip stock SMMT
# no finance data skip stock GRP-UN
# no finance data skip stock IIJIY
# no finance data skip stock BBMPY
# no finance data skip stock NOMD
# no finance data skip stock GTBIF
# no finance data skip stock AFLYY
# no finance data skip stock SEDG
# no finance data skip stock KOZAY
# no finance data skip stock QDEL
# no finance data skip stock SHZNY
# no finance data skip stock AKO-A
# no finance data skip stock NAD
# no finance data skip stock PEGRY
# no finance data skip stock MTX
# no finance data skip stock EXG
# no finance data skip stock DFIHY
# no finance data skip stock NHNKY
# no finance data skip stock ADX
# no finance data skip stock OSTIY
# no finance data skip stock LGF-A
# no finance data skip stock MIR
# no finance data skip stock VCEL
# no finance data skip stock NZF
# no finance data skip stock JPC
# no finance data skip stock UTF
# no finance data skip stock MYGN
# no finance data skip stock AZZ
# no finance data skip stock RNW
# no finance data skip stock UTG
# no finance data skip stock TCNNF
# no finance data skip stock CRGY
# no finance data skip stock ETY
# no finance data skip stock GDV
# no finance data skip stock BRP
# no finance data skip stock MBUMY
# no finance data skip stock JBI
# no finance data skip stock AQPW
# no finance data skip stock LIFX
# no finance data skip stock MRRTY
# no finance data skip stock GOF
# no finance data skip stock USA
# no finance data skip stock HLMN
# no finance data skip stock MGPI
# no finance data skip stock NUV
# no finance data skip stock ASTH
# no finance data skip stock CLM
# no finance data skip stock EVT
# no finance data skip stock VRNOF
# no finance data skip stock OUTKY
# no finance data skip stock FNMA
# no finance data skip stock NEXT
# no finance data skip stock RVT
# no finance data skip stock CLBK
# no finance data skip stock KYN
# no finance data skip stock AILIH
# no finance data skip stock GAB
# no finance data skip stock TLRY
# no finance data skip stock NAC
# no finance data skip stock TY
# no finance data skip stock CMRF
# no finance data skip stock RQI
# no finance data skip stock AHL-PC
# no finance data skip stock ETV
# no finance data skip stock HYT
# no finance data skip stock BXMX
# no finance data skip stock CARCY
# no finance data skip stock NISUY
# no finance data skip stock GPRE
# no finance data skip stock NFJ
# no finance data skip stock NWTN
# no finance data skip stock NMZ
# no finance data skip stock JFR
# no finance data skip stock BIOGY
# no finance data skip stock CIFR
# no finance data skip stock QQQX
# no finance data skip stock CRAI
# no finance data skip stock GAM
# no finance data skip stock MIESY
# no finance data skip stock CSR
# no finance data skip stock PTA
# no finance data skip stock EOS
# no finance data skip stock FPF
# no finance data skip stock AUTL
# no finance data skip stock MUC
# no finance data skip stock MFIC
# no finance data skip stock EAI
# no finance data skip stock CATX
# no finance data skip stock PBAJ
# no finance data skip stock RNP
# no finance data skip stock BBN
# no finance data skip stock VTOL
# no finance data skip stock SBR
# no finance data skip stock NRK
# no finance data skip stock WNLV
# no finance data skip stock FSUN
# no finance data skip stock NESR
# no finance data skip stock AWF
# no finance data skip stock FMCC
# no finance data skip stock ETW
# no finance data skip stock MUI
# no finance data skip stock HQH
# no finance data skip stock AAPI
# no finance data skip stock MQY
# no finance data skip stock AOD
# no finance data skip stock GOLLQ
# no finance data skip stock CRF
# no finance data skip stock MDRX
# no finance data skip stock ALPC
# no finance data skip stock FMCB
# no finance data skip stock JQC
# no finance data skip stock BIOX
# no finance data skip stock MYI
# no finance data skip stock EOI
# no finance data skip stock KUBR
# no finance data skip stock PHK
# no finance data skip stock HTD
# no finance data skip stock IGR
# no finance data skip stock CRLBF
# no finance data skip stock HUT
# no finance data skip stock SPTN
# no finance data skip stock QDMI
# no finance data skip stock ZUUS
# no finance data skip stock PCN
# no finance data skip stock NXP
# no finance data skip stock SDA
# no finance data skip stock WULF
# no finance data skip stock GLASF
# no finance data skip stock VVR
# no finance data skip stock ETH
# no finance data skip stock CYRX
# no finance data skip stock NDMO
# no finance data skip stock VMO
# no finance data skip stock BH-A
# no finance data skip stock FAX
# no finance data skip stock PFN
# no finance data skip stock EYPT
# no finance data skip stock GGN
# no finance data skip stock SNDL
# no finance data skip stock ENGN
# no finance data skip stock GMGI
# no finance data skip stock MHD
# no finance data skip stock NIE
# no finance data skip stock PBT
# no finance data skip stock VSLAX
# no finance data skip stock RUPRF
# no finance data skip stock NWBO
# no finance data skip stock HBIA
# no finance data skip stock MUJ
# no finance data skip stock PEO
# no finance data skip stock TSNDF
# no finance data skip stock FRPH
# no finance data skip stock REPX
# no finance data skip stock LDP
# no finance data skip stock PDT
# no finance data skip stock NKX
# no finance data skip stock ETJ
# no finance data skip stock BHK
# no finance data skip stock ADSE
# no finance data skip stock EUBG
# no finance data skip stock MMU
# no finance data skip stock PML
# no finance data skip stock IFN
# no finance data skip stock IIM
# no finance data skip stock IOCJY
# no finance data skip stock VGM
# no finance data skip stock VKQ
# no finance data skip stock WIW
# no finance data skip stock AWCA
# no finance data skip stock DIAX
# no finance data skip stock GDOT
# no finance data skip stock STK
# no finance data skip stock DSU
# no finance data skip stock IQI
# no finance data skip stock TBLD
# no finance data skip stock HNOI
# no finance data skip stock HTBI
# no finance data skip stock NXJ
# no finance data skip stock EXOD
# no finance data skip stock MYD
# no finance data skip stock HPS
# no finance data skip stock BLW
# no finance data skip stock FUFU
# no finance data skip stock GHY
# no finance data skip stock RMT
# no finance data skip stock FRA
# no finance data skip stock VCV
# no finance data skip stock GUT
# no finance data skip stock TBPH
# no finance data skip stock MMD
# no finance data skip stock CRD-A
# no finance data skip stock MVF
# no finance data skip stock HPI
# no finance data skip stock LTCN
# no finance data skip stock NQP
# no finance data skip stock BFK
# no finance data skip stock PCOK
# no finance data skip stock JPI
# no finance data skip stock NML
# no finance data skip stock HFRO
# no finance data skip stock AERG
# no finance data skip stock INRE
# no finance data skip stock NLCP
# no finance data skip stock MUA
# no finance data skip stock VRDR
# no finance data skip stock ISD
# no finance data skip stock IGD
# no finance data skip stock ETB
# no finance data skip stock MYN
# no finance data skip stock EAD
# no finance data skip stock PTSI
# no finance data skip stock HQL
# no finance data skip stock MCI
# no finance data skip stock MCS
# no finance data skip stock FFA
# no finance data skip stock VKI
# no finance data skip stock GBAB
# no finance data skip stock KTF
# no finance data skip stock HPF
# no finance data skip stock BCHG
# no finance data skip stock GOAI
# no finance data skip stock HIO
# no finance data skip stock TELL
# no finance data skip stock UNTC
# no finance data skip stock SOR
# no finance data skip stock ASA
# no finance data skip stock HEAR
# no finance data skip stock PPT
# no finance data skip stock YUMM
# no finance data skip stock ARDC
# no finance data skip stock NAN
# no finance data skip stock BRT
# no finance data skip stock GDRZF
# no finance data skip stock NLST
# no finance data skip stock MIY
# no finance data skip stock ABIT
# no finance data skip stock PMO
# no finance data skip stock FOF
# no finance data skip stock PFL
# no finance data skip stock MHN
# no finance data skip stock JRI
# no finance data skip stock VADP
# no finance data skip stock CDRO
# no finance data skip stock SCGY
# no finance data skip stock ABXXF
# no finance data skip stock ASG
# no finance data skip stock RFI
# no finance data skip stock BRW
# no finance data skip stock PROC
# no finance data skip stock FGPR
# no finance data skip stock NBH
# no finance data skip stock GDLC
# no finance data skip stock BGT
# no finance data skip stock MIN
# no finance data skip stock JGH
# no finance data skip stock OIA
# no finance data skip stock ANVI
# no finance data skip stock RM
# no finance data skip stock ADAP
# no finance data skip stock NCA
# no finance data skip stock NCV
# no finance data skip stock SDSYA
# no finance data skip stock SSCC
# no finance data skip stock FLJ
# no finance data skip stock PMM
# no finance data skip stock PLL
# no finance data skip stock SPXX
# no finance data skip stock MG
# no finance data skip stock SMBMY
# no finance data skip stock TWN
# no finance data skip stock MXF
# no finance data skip stock NVX
# no finance data skip stock MTA
# no finance data skip stock AYRWF
# no finance data skip stock FCT
# no finance data skip stock AAWH
# no finance data skip stock RCS
# no finance data skip stock MCR
# no finance data skip stock HYI
# no finance data skip stock MMT
# no finance data skip stock BLDE
# no finance data skip stock GROY
# no finance data skip stock CYBN
# no finance data skip stock TEI
# no finance data skip stock FTF
# no finance data skip stock ERC
# no finance data skip stock PMX
# no finance data skip stock BKT
# no finance data skip stock VPV
# no finance data skip stock NUW
# no finance data skip stock AGD
# no finance data skip stock PMF
# no finance data skip stock RDZN
# no finance data skip stock FUND
# no finance data skip stock DC
# no finance data skip stock INSE
# no finance data skip stock IIF
# no finance data skip stock HAWEL
# no finance data skip stock PSF
# no finance data skip stock MTWO
# no finance data skip stock JCE
# no finance data skip stock ICTSF
# no finance data skip stock NTPIF
# no finance data skip stock MQT
# no finance data skip stock MVT
# no finance data skip stock RBTK
# no finance data skip stock JOF
# no finance data skip stock CAF
# no finance data skip stock TSI
# no finance data skip stock TDF
# no finance data skip stock MUE
# no finance data skip stock NCZ
# no finance data skip stock WEWA
# no finance data skip stock SABA
# no finance data skip stock RCEL
# no finance data skip stock GLO
# no finance data skip stock MFM
# no finance data skip stock RMBL
# no finance data skip stock JRS
# no finance data skip stock DHY
# no finance data skip stock GPJA
# no finance data skip stock HIE
# no finance data skip stock BKN
# no finance data skip stock VTN
# no finance data skip stock NHS
# no finance data skip stock MHI
# no finance data skip stock OCN
# no finance data skip stock SJT
# no finance data skip stock ETX
# no finance data skip stock KGNR
# no finance data skip stock NPV
# no finance data skip stock BNIGF
# no finance data skip stock EMF
# no finance data skip stock EMP
# no finance data skip stock KNIT
# no finance data skip stock WIA
# no finance data skip stock PCK
# no finance data skip stock IGI
# no finance data skip stock LMDXF
# no finance data skip stock GDO
# no finance data skip stock ENJ
# no finance data skip stock CTGO
# no finance data skip stock CFNB
# no finance data skip stock PCQ
# no finance data skip stock YS
# no finance data skip stock VBF
# no finance data skip stock INSI
# no finance data skip stock WTRV
# no finance data skip stock PIIVX
# no finance data skip stock CORBF
# no finance data skip stock BXSY
# no finance data skip stock EACO
# no finance data skip stock MPV
# no finance data skip stock HQI
# no finance data skip stock PZC
# no finance data skip stock NHHS
# no finance data skip stock NRO
# no finance data skip stock GGT
# no finance data skip stock NNY
# no finance data skip stock MPA
# no finance data skip stock ALYAF
# no finance data skip stock PIM
# no finance data skip stock GRX
# no finance data skip stock IDE
# no finance data skip stock ARAT
# no finance data skip stock LDDD
# no finance data skip stock MCN
# no finance data skip stock GRUSF
# no finance data skip stock BMN
# no finance data skip stock CNXX
# no finance data skip stock PLNH
# no finance data skip stock MHF
# no finance data skip stock GF
# no finance data skip stock VXRT
# no finance data skip stock CYDY
# no finance data skip stock RPMT
# no finance data skip stock CRAWA
# no finance data skip stock MSD
# no finance data skip stock SPE
# no finance data skip stock FNRN
# no finance data skip stock OAKC
# no finance data skip stock CHHE
# no finance data skip stock MDNAF
# no finance data skip stock ACRG
# no finance data skip stock IGA
# no finance data skip stock BTA
# no finance data skip stock ELTP
# no finance data skip stock ISBA
# no finance data skip stock KBLB
# no finance data skip stock JUSHF
# no finance data skip stock DMO
# no finance data skip stock PFD
# no finance data skip stock JHS
# no finance data skip stock CBSTF
# no finance data skip stock THM
# no finance data skip stock HCIL
# no finance data skip stock FMN
# no finance data skip stock BBXIA
# no finance data skip stock SFRX
# no finance data skip stock WEA
# no finance data skip stock VNJA
# no finance data skip stock FREVS
# no finance data skip stock HEQ
# no finance data skip stock NAZ
# no finance data skip stock AENT
# no finance data skip stock RMGCF
# no finance data skip stock ITHUF
# no finance data skip stock CWGL
# no finance data skip stock GLQ
# no finance data skip stock ESGH
# no finance data skip stock PHD
# no finance data skip stock MHGU
# no finance data skip stock PHX
# no finance data skip stock HNVR
# no finance data skip stock JHI
# no finance data skip stock CZWI
# no finance data skip stock LIFE
# no finance data skip stock KF
# no finance data skip stock IAF
# no finance data skip stock FTCO
# no finance data skip stock PCF
# no finance data skip stock CCFN
# no finance data skip stock PAI
# no finance data skip stock CRGO
# no finance data skip stock CHN
# no finance data skip stock ASFH
# no finance data skip stock CSTAF
# no finance data skip stock MVO
# no finance data skip stock BDCO
# no finance data skip stock NIM
# no finance data skip stock SBI
# no finance data skip stock SRV
# no finance data skip stock ECF
# no finance data skip stock AFBI
# no finance data skip stock PFO
# no finance data skip stock SPPP
# no finance data skip stock LICY
# no finance data skip stock RLMD
# no finance data skip stock CBAT
# no finance data skip stock KSM
# no finance data skip stock AREC
# no finance data skip stock DRTTF
# no finance data skip stock BSEM
# no finance data skip stock CSBB
# no finance data skip stock YBGJ
# no finance data skip stock PCM
# no finance data skip stock EBMT
# no finance data skip stock NOBH
# no finance data skip stock BLGO
# no finance data skip stock RTC
# no finance data skip stock SWZ
# no finance data skip stock ERDCF
# no finance data skip stock EMYB
# no finance data skip stock FFMGF
# no finance data skip stock CXDO
# no finance data skip stock YCQH
# no finance data skip stock EFSI
# no finance data skip stock LVPA
# no finance data skip stock WPRT
# no finance data skip stock FNWB
# no finance data skip stock LGYV
# no finance data skip stock RSTN
# no finance data skip stock MGF
# no finance data skip stock REEMF
# no finance data skip stock VOC
# no finance data skip stock NMT
# no finance data skip stock GGZ
# no finance data skip stock BMBN
# no finance data skip stock MRMD
# no finance data skip stock ORMP
# no finance data skip stock KLXE
# no finance data skip stock HNW
# no finance data skip stock GECC
# no finance data skip stock IHD
# no finance data skip stock JLS
# no finance data skip stock FOTB
# no finance data skip stock BFGX
# no finance data skip stock FFNTF
# no finance data skip stock NMI
# no finance data skip stock UTGN
# no finance data skip stock VUZI
# no finance data skip stock ZHYBF
# no finance data skip stock TPZ
# no finance data skip stock ERH
# no finance data skip stock CMTV
# no finance data skip stock WSTRF
# no finance data skip stock BCV
# no finance data skip stock AVAI
# no finance data skip stock BBUZ
# no finance data skip stock KANP
# no finance data skip stock GNT
# no finance data skip stock FLFV
# no finance data skip stock USCTF
# no finance data skip stock ORRCF
# no finance data skip stock PYYX
# no finance data skip stock PNRLF
# no finance data skip stock GLU
# no finance data skip stock PGP
# no finance data skip stock ENBP
# no finance data skip stock LOMLF
# no finance data skip stock NXC
# no finance data skip stock VGI
# no finance data skip stock CRT
# no finance data skip stock QNBC
# no finance data skip stock PSBQ
# no finance data skip stock CYRB
# no finance data skip stock PNI
# no finance data skip stock GGAAF
# no finance data skip stock WRPT
# no finance data skip stock FKYS
# no finance data skip stock PYRGF
# no finance data skip stock PTZH
# no finance data skip stock PVCT
# no finance data skip stock RDGL
# no finance data skip stock MDIA
# no finance data skip stock PSIX
# no finance data skip stock ACOGF
# no finance data skip stock FCO
# no finance data skip stock GDNSF
# no finance data skip stock MPIR
# no finance data skip stock SSNT
# no finance data skip stock NANX
# no finance data skip stock SFDL
# no finance data skip stock ODYS
# no finance data skip stock CEV
# no finance data skip stock LTCH
# no finance data skip stock HYSR
# no finance data skip stock JRSS
# no finance data skip stock QSJC
# no finance data skip stock PFBX
# no finance data skip stock TIHE
# no finance data skip stock NGLD
# no finance data skip stock STCB
# no finance data skip stock SSIC
# no finance data skip stock IAE
# no finance data skip stock HRBR
# no finance data skip stock GRAM
# no finance data skip stock PMHG
# no finance data skip stock VLT
# no finance data skip stock DWNX
# no finance data skip stock AIRRF
# no finance data skip stock BCRD
# no finance data skip stock ARQQ
# no finance data skip stock RGT
# no finance data skip stock PGZ
# no finance data skip stock TTP
# no finance data skip stock AVNI
# no finance data skip stock BTTC
# no finance data skip stock IHTA
# no finance data skip stock DMA
# no finance data skip stock CPTP
# no finance data skip stock MFD
# no finance data skip stock GTII
# no finance data skip stock PFIE
# no finance data skip stock BCTF
# no finance data skip stock GGROU
# no finance data skip stock AUGG
# no finance data skip stock GVXXF
# no finance data skip stock FAM
# no finance data skip stock KWIK
# no finance data skip stock SLBK
# no finance data skip stock UNIB
# no finance data skip stock BUUZ
# no finance data skip stock LDTC
# no finance data skip stock CEE
# no finance data skip stock EZOO
# no finance data skip stock FGNV
# no finance data skip stock NMS
# no finance data skip stock AITX
# no finance data skip stock GRYP
# no finance data skip stock FLCX
# no finance data skip stock RSKIA
# no finance data skip stock IRME
# no finance data skip stock NWPP
# no finance data skip stock EEA
# no finance data skip stock IQST
# no finance data skip stock RTGN
# no finance data skip stock EGRX
# no finance data skip stock TGLO
# no finance data skip stock CNFN
# no finance data skip stock PNF
# no finance data skip stock REDW
# no finance data skip stock HFUS
# no finance data skip stock CHMX
# no finance data skip stock FURY
# no finance data skip stock KSBI
# no finance data skip stock MUGH
# no finance data skip stock FSRN
# no finance data skip stock EUDA
# no finance data skip stock ANLDF
# no finance data skip stock BUKS
# no finance data skip stock JUVF
# no finance data skip stock PHUN
# no finance data skip stock GSVRF
# no finance data skip stock FMBM
# no finance data skip stock SVRSF
# no finance data skip stock NDP
# no finance data skip stock LTRPA
# no finance data skip stock JMM
# no finance data skip stock AVRO
# no finance data skip stock UWHR
# no finance data skip stock SPAZF
# no finance data skip stock LQMT
# no finance data skip stock COPR
# no finance data skip stock GBUX
# no finance data skip stock CBKM
# no finance data skip stock WHEN
# no finance data skip stock ETST
# no finance data skip stock VPLM
# no finance data skip stock CJET
# no finance data skip stock NUVR
# no finance data skip stock FMY
# no finance data skip stock UMEWF
# no finance data skip stock LVER
# no finance data skip stock FMFG
# no finance data skip stock MXE
# no finance data skip stock PVL
# no finance data skip stock IVFH
# no finance data skip stock PRT
# no finance data skip stock CXXIF
# no finance data skip stock CACO
# no finance data skip stock WMLLF
# no finance data skip stock RVPH
# no finance data skip stock SMDRF
# no finance data skip stock BPT
# no finance data skip stock KPEA
# no finance data skip stock LEAT
# no finance data skip stock NXN
# no finance data skip stock UNXP
# no finance data skip stock RFLFY
# no finance data skip stock ACRHF
# no finance data skip stock DYNR
# no finance data skip stock VASO
# no finance data skip stock CPTN
# no finance data skip stock VIVC
# no finance data skip stock GCEH
# no finance data skip stock UEEC
# no finance data skip stock AIRE
# no finance data skip stock DWSN
# no finance data skip stock ZNOG
# no finance data skip stock AKTS
# no finance data skip stock LONCF
# no finance data skip stock XTGRF
# no finance data skip stock CENN
# no finance data skip stock AKOM
# no finance data skip stock GAME
# no finance data skip stock SHWZ
# no finance data skip stock SUND
# no finance data skip stock JANL
# no finance data skip stock BFNH
# no finance data skip stock NOTR
# no finance data skip stock NXMH
# no finance data skip stock TECTP
# no finance data skip stock RMRI
# no finance data skip stock LRDC
# no finance data skip stock ELMSQ
# no finance data skip stock RNGE
# no finance data skip stock KDOZF
# no finance data skip stock PLTN
# no finance data skip stock GSHRF
# no finance data skip stock nan
# no finance data skip stock MSCLF
# no finance data skip stock GLXZ
# no finance data skip stock GUER
# no finance data skip stock PGID
# no finance data skip stock SODI
# no finance data skip stock CUBA
# no finance data skip stock PHCI
# no finance data skip stock WBQNL
# no finance data skip stock GRF
# no finance data skip stock BNET
# no finance data skip stock MULN
# no finance data skip stock BHLL
# no finance data skip stock MALG
# no finance data skip stock FCCI
# no finance data skip stock CAHO
# no finance data skip stock FDIT
# no finance data skip stock CTRM
# no finance data skip stock PNXP
# no finance data skip stock MPAD
# no finance data skip stock GLGI
# no finance data skip stock ALMU
# no finance data skip stock PRKA
# no finance data skip stock HANNF
# no finance data skip stock LUDG
# no finance data skip stock GWSO
# no finance data skip stock MFON
# no finance data skip stock PYN
# no finance data skip stock AGXPF
# no finance data skip stock PXPC
# no finance data skip stock HRGN
# no finance data skip stock BKUH
# no finance data skip stock GXSFF
# no finance data skip stock BMNR
# no finance data skip stock UURAF
# no finance data skip stock JETMF
# no finance data skip stock INFT
# no finance data skip stock RWOD
# no finance data skip stock BTQQF
# no finance data skip stock AUSI
# no finance data skip stock LNBY
# no finance data skip stock IGXT
# no finance data skip stock PIAC
# no finance data skip stock TISI
# no finance data skip stock AAGH
# no finance data skip stock VWFB
# no finance data skip stock CRVW
# no finance data skip stock NYMXF
# no finance data skip stock BIMT
# no finance data skip stock AACG
# no finance data skip stock RSRV
# no finance data skip stock LPCN
# no finance data skip stock LISMF
# no finance data skip stock INVU
# no finance data skip stock NRDE
# no finance data skip stock NOWG
# no finance data skip stock NNUP
# no finance data skip stock YERBF
# no finance data skip stock CWBHF
# no finance data skip stock KTEL
# no finance data skip stock LDSN
# no finance data skip stock ITXXF
# no finance data skip stock CRCUF
# no finance data skip stock ABTS
# no finance data skip stock NSGP
# no finance data skip stock AAQL
# no finance data skip stock CETI
# no finance data skip stock ONEI
# no finance data skip stock HWTR
# no finance data skip stock AXREF
# no finance data skip stock QNTO
# no finance data skip stock CHUC
# no finance data skip stock GEVI
# no finance data skip stock XITO
# no finance data skip stock GTMAY
# no finance data skip stock NPFC
# no finance data skip stock APHP
# no finance data skip stock CEI
# no finance data skip stock TMRC
# no finance data skip stock HTOO
# no finance data skip stock SCIA
# no finance data skip stock NOM
# no finance data skip stock PCSV
# no finance data skip stock INTI
# no finance data skip stock GLAI
# no finance data skip stock NCNC
# no finance data skip stock SNWV
# no finance data skip stock QYOUF
# no finance data skip stock LCGMF
# no finance data skip stock HSTI
# no finance data skip stock AGSS
# no finance data skip stock BRWC
# no finance data skip stock VINC
# no finance data skip stock DMTK
# no finance data skip stock ACFN
# no finance data skip stock EQMEF
# no finance data skip stock QZMRF
# no finance data skip stock CRMZ
# no finance data skip stock LILIF
# no finance data skip stock PGTK
# no finance data skip stock CLRO
# no finance data skip stock CREV
# no finance data skip stock GNRV
# no finance data skip stock CHKR
# no finance data skip stock GEBRF
# no finance data skip stock SFCO
# no finance data skip stock SLDX
# no finance data skip stock YTFD
# no finance data skip stock LWLW
# no finance data skip stock TSSI
# no finance data skip stock GTEC
# no finance data skip stock AXDX
# no finance data skip stock MMTIF
# no finance data skip stock BIXT
# no finance data skip stock FUST
# no finance data skip stock APTO
# no finance data skip stock HGTXU
# no finance data skip stock ELRE
# no finance data skip stock SUIC
# no finance data skip stock TBTC
# no finance data skip stock SPND
# no finance data skip stock SCTH
# no finance data skip stock RMSL
# no finance data skip stock EESH
# no finance data skip stock SVMB
# no finance data skip stock JGLDF
# no finance data skip stock ARGC
# no finance data skip stock MXROF
# no finance data skip stock PHGE
# no finance data skip stock VMNT
# no finance data skip stock CLOQ
# no finance data skip stock SKKY
# no finance data skip stock IMTH
# no finance data skip stock TGEN
# no finance data skip stock QURT
# no finance data skip stock TLRS
# no finance data skip stock LIFD
# no finance data skip stock DFCO
# no finance data skip stock HMMR
# no finance data skip stock PCST
# no finance data skip stock LBSR
# no finance data skip stock INIS
# no finance data skip stock BENF
# no finance data skip stock ITMSF
# no finance data skip stock EQTRF
# no finance data skip stock ABCP
# no finance data skip stock RLFTY
# no finance data skip stock PBSV
# no finance data skip stock QMCI
# no finance data skip stock TETOF
# no finance data skip stock NBIO
# no finance data skip stock SRLZF
# no finance data skip stock RBNK
# no finance data skip stock KENS
# no finance data skip stock GFGSF
# no finance data skip stock EBIXQ
# no finance data skip stock EXDW
# no finance data skip stock HLYK
# no finance data skip stock PFSB
# no finance data skip stock ALID
# no finance data skip stock ILUS
# no finance data skip stock TRFE
# no finance data skip stock AUCUF
# no finance data skip stock WNDW
# no finance data skip stock OGGIF
# no finance data skip stock QREE
# no finance data skip stock PUBC
# no finance data skip stock GOLQ
# no finance data skip stock UGEIF
# no finance data skip stock NPLS
# no finance data skip stock CFOO
# no finance data skip stock NMGX
# no finance data skip stock CLRD
# no finance data skip stock OTLC
# no finance data skip stock INRD
# no finance data skip stock OCLN
# no finance data skip stock HLRTF
# no finance data skip stock MTR
# no finance data skip stock SPRS
# no finance data skip stock STLY
# no finance data skip stock YJGJ
# no finance data skip stock RXMD
# no finance data skip stock MAPPF
# no finance data skip stock UPHL
# no finance data skip stock VYEY
# no finance data skip stock APGTQ
# no finance data skip stock MTBLY
# no finance data skip stock NFTN
# no finance data skip stock VICP
# no finance data skip stock GRHI
# no finance data skip stock VPRB
# no finance data skip stock MMAT
# no finance data skip stock INKW
# no finance data skip stock CYCA
# no finance data skip stock EDSA
# no finance data skip stock QSEP
# no finance data skip stock PHIL
# no finance data skip stock MSBB
# no finance data skip stock SNTW
# no finance data skip stock NMEX
# no finance data skip stock SDCH
# no finance data skip stock RSMXF
# no finance data skip stock SRRE
# no finance data skip stock MCLDF
# no finance data skip stock SMREF
# no finance data skip stock PAYD
# no finance data skip stock RLBY
# no finance data skip stock IONI
# no finance data skip stock EDXC
# no finance data skip stock ARRKF
# no finance data skip stock ALRTF
# no finance data skip stock EGYF
# no finance data skip stock AVCRF
# no finance data skip stock AIRO
# no finance data skip stock TNLX
# no finance data skip stock EOSS
# no finance data skip stock HWNI
# no finance data skip stock SLGD
# no finance data skip stock AVOI
# no finance data skip stock PGFF
# no finance data skip stock DLA
# no finance data skip stock RCG
# no finance data skip stock GXXY
# no finance data skip stock BMMJ
# no finance data skip stock TRLEF
# no finance data skip stock PAANF
# no finance data skip stock PNYG
# no finance data skip stock SKAS
# no finance data skip stock VVPR
# no finance data skip stock VAUCF
# no finance data skip stock ABVC
# no finance data skip stock AIJTY
# no finance data skip stock BKUCF
# no finance data skip stock XESP
# no finance data skip stock EZFL
# no finance data skip stock SPGX
# no finance data skip stock WEWKQ
# no finance data skip stock TGGI
# no finance data skip stock CLEV
# no finance data skip stock BRST
# no finance data skip stock GOVB
# no finance data skip stock CANN
# no finance data skip stock TLLTF
# no finance data skip stock BETRF
# no finance data skip stock RLBD
# no finance data skip stock LKCO
# no finance data skip stock LCTC
# no finance data skip stock DSNY
# no finance data skip stock LOGQ
# no finance data skip stock TCRI
# no finance data skip stock HLGN
# no finance data skip stock MHUBF
# no finance data skip stock SPFX
# no finance data skip stock MSTH
# no finance data skip stock MTPP
# no finance data skip stock EBZT
# no finance data skip stock HMBL
# no finance data skip stock SLTN
# no finance data skip stock MMTRS
# no finance data skip stock BUDZ
# no finance data skip stock RMHB
# no finance data skip stock CRWE
# no finance data skip stock QIND
# no finance data skip stock PFHO
# no finance data skip stock GOGR
# no finance data skip stock NROM
# no finance data skip stock TGCB
# no finance data skip stock APYP
# no finance data skip stock TPHS
# no finance data skip stock USNU
# no finance data skip stock LEBGF
# no finance data skip stock ASRE
# no finance data skip stock TRBMF
# no finance data skip stock MCUJF
# no finance data skip stock KLNG
# no finance data skip stock JUPGF
# no finance data skip stock HCNWF
# no finance data skip stock SHMP
# no finance data skip stock RYES
# no finance data skip stock MARPS
# no finance data skip stock CVSI
# no finance data skip stock NBND
# no finance data skip stock RASP
# no finance data skip stock BMNM
# no finance data skip stock PURE
# no finance data skip stock OLKR
# no finance data skip stock NAHD
# no finance data skip stock FXBY
# no finance data skip stock KEYR
# no finance data skip stock PKKFF
# no finance data skip stock SNBH
# no finance data skip stock DPLS
# no finance data skip stock UPYY
# no finance data skip stock ZKGCF
# no finance data skip stock ECTM
# no finance data skip stock SBIG
# no finance data skip stock NSFDF
# no finance data skip stock OZSC
# no finance data skip stock TIGCF
# no finance data skip stock BRVO
# no finance data skip stock CRYM
# no finance data skip stock CDSG
# no finance data skip stock RDGA
# no finance data skip stock KIQSF
# no finance data skip stock CBLO
# no finance data skip stock CLSH
# no finance data skip stock HITC
# no finance data skip stock FCCN
# no finance data skip stock ZDPY
# no finance data skip stock TENX
# no finance data skip stock FDCT
# no finance data skip stock GESI
# no finance data skip stock BICX
# no finance data skip stock CLRI
# no finance data skip stock WHLT
# no finance data skip stock PBMLF
# no finance data skip stock ZEOX
# no finance data skip stock HEPA
# no finance data skip stock ICCO
# no finance data skip stock GHST
# no finance data skip stock PULM
# no finance data skip stock LVRLF
# no finance data skip stock INBP
# no finance data skip stock SENR
# no finance data skip stock NMREF
# no finance data skip stock IVDN
# no finance data skip stock TIKK
# no finance data skip stock IAALF
# no finance data skip stock SRNW
# no finance data skip stock ELYS
# no finance data skip stock IDXG
# no finance data skip stock SONX
# no finance data skip stock DEFG
# no finance data skip stock PTOP
# no finance data skip stock FHLD
# no finance data skip stock ACBM
# no finance data skip stock CMOT
# no finance data skip stock GARWF
# no finance data skip stock SNRG
# no finance data skip stock CBIH
# no finance data skip stock ENZN
# no finance data skip stock BMXC
# no finance data skip stock BRSH
# no finance data skip stock LGIQ
# no finance data skip stock FWBI
# no finance data skip stock BLMH
# no finance data skip stock FEMFF
# no finance data skip stock VIDE
# no finance data skip stock BZYR
# no finance data skip stock HSTC
# no finance data skip stock LEAI
# no finance data skip stock AYRO
# no finance data skip stock MICS
# no finance data skip stock BMXI
# no finance data skip stock PKTX
# no finance data skip stock JPOTF
# no finance data skip stock STEK
# no finance data skip stock EMMA
# no finance data skip stock VAPO
# no finance data skip stock MOJO
# no finance data skip stock KNGRF
# no finance data skip stock AHNR
# no finance data skip stock NORD
# no finance data skip stock SPTY
# no finance data skip stock MARK
# no finance data skip stock GPOX
# no finance data skip stock BABB
# no finance data skip stock THMO
# no finance data skip stock QLIS
# no finance data skip stock NULGF
# no finance data skip stock ADMT
# no finance data skip stock SCYYF
# no finance data skip stock DHCC
# no finance data skip stock INTV
# no finance data skip stock SONN
# no finance data skip stock SVBL
# no finance data skip stock OOGI
# no finance data skip stock FFLO
# no finance data skip stock MOBQ
# no finance data skip stock ORMNF
# no finance data skip stock USDR
# no finance data skip stock CBMJ
# no finance data skip stock GEGP
# no finance data skip stock FRCB
# no finance data skip stock NUMD
# no finance data skip stock RAYT
# no finance data skip stock NRIS
# no finance data skip stock BLNC
# no finance data skip stock REED
# no finance data skip stock RSCF
# no finance data skip stock LFEV
# no finance data skip stock HSTA
# no finance data skip stock ARTH
# no finance data skip stock DTGI
# no finance data skip stock FULO
# no finance data skip stock NEWH
# no finance data skip stock SPEV
# no finance data skip stock GRPS
# no finance data skip stock NVSGF
# no finance data skip stock ECIA
# no finance data skip stock STAL
# no finance data skip stock OWPC
# no finance data skip stock LUVU
# no finance data skip stock VSMR
# no finance data skip stock NSTGQ
# no finance data skip stock ABTI
# no finance data skip stock DBMM
# no finance data skip stock ARTL
# no finance data skip stock CXXMF
# no finance data skip stock SRAX
# no finance data skip stock BWMG
# no finance data skip stock BEGI
# no finance data skip stock BGAVF
# no finance data skip stock TARSF
# no finance data skip stock KLDI
# no finance data skip stock LTUM
# no finance data skip stock PGOL
# no finance data skip stock LEJUY
# no finance data skip stock JUVAF
# no finance data skip stock NLSC
# no finance data skip stock VYND
# no finance data skip stock RWGI
# no finance data skip stock OGAA
# no finance data skip stock BKTPF
# no finance data skip stock ELVG
# no finance data skip stock TOFB
# no finance data skip stock GBNHF
# no finance data skip stock GLVT
# no finance data skip stock RAHGF
# no finance data skip stock WOLV
# no finance data skip stock GWTI
# no finance data skip stock LGCP
# no finance data skip stock VSOLF
# no finance data skip stock SVMH
# no finance data skip stock LQLY
# no finance data skip stock TRCK
# no finance data skip stock QWTR
# no finance data skip stock PCMC
# no finance data skip stock KOAN
# no finance data skip stock ABCFF
# no finance data skip stock TNRG
# no finance data skip stock EBET
# no finance data skip stock AETHF
# no finance data skip stock SRCO
# no finance data skip stock ZPHYF
# no finance data skip stock SHMY
# no finance data skip stock MAGE
# no finance data skip stock DROR
# no finance data skip stock ADAD
# no finance data skip stock IWSH
# no finance data skip stock SAML
# no finance data skip stock ECGR
# no finance data skip stock OVTZ
# no finance data skip stock MNKA
# no finance data skip stock BWMY
# no finance data skip stock CBDY
# no finance data skip stock EIGRQ
# no finance data skip stock SEAV
# no finance data skip stock IPCIF
# no finance data skip stock SFIO
# no finance data skip stock KRBP
# no finance data skip stock GSBX
# no finance data skip stock ROYL
# no finance data skip stock OHCS
# no finance data skip stock ECRO
# no finance data skip stock UCLE
# no finance data skip stock BTAX
# no finance data skip stock IMII
# no finance data skip stock USLG
# no finance data skip stock MACE
# no finance data skip stock MYCB
# no finance data skip stock VNUE
# no finance data skip stock GULTU
# no finance data skip stock KCRD
# no finance data skip stock GTLL
# no finance data skip stock BLIS
# no finance data skip stock TRXA
# no finance data skip stock CWBR
# no finance data skip stock CPMV
# no finance data skip stock ODYY
# no finance data skip stock GEMZ
# no finance data skip stock OMQS
# no finance data skip stock FMNJ
# no finance data skip stock GMVDF
# no finance data skip stock ELOX
# no finance data skip stock CNNC
# no finance data skip stock CVAT
# no finance data skip stock SEVCF
# no finance data skip stock NSTM
# no finance data skip stock SRMX
# no finance data skip stock VFRM
# no finance data skip stock ARDS
# no finance data skip stock TLCC
# no finance data skip stock REPCF
# no finance data skip stock QPRC
# no finance data skip stock BASA
# no finance data skip stock AXIM
# no finance data skip stock GBLX
# no finance data skip stock ARAO
# no finance data skip stock VYCO
# no finance data skip stock VHAI
# no finance data skip stock FWFW
# no finance data skip stock ALTX
# no finance data skip stock DMSL
# no finance data skip stock WLYW
# no finance data skip stock LBUY
# no finance data skip stock THMG
# no finance data skip stock FMHS
# no finance data skip stock DQWS
# no finance data skip stock CRTG
# no finance data skip stock QRON
# no finance data skip stock FDOC
# no finance data skip stock BRQSF
# no finance data skip stock CBDW
# no finance data skip stock NVDEF
# no finance data skip stock PLSH
# no finance data skip stock SRGZ
# no finance data skip stock AVRW
# no finance data skip stock IPSI
# no finance data skip stock CRKN
# no finance data skip stock BPTSY
# no finance data skip stock XYLB
# no finance data skip stock SIVBQ
# no finance data skip stock ENRT
# no finance data skip stock TSOI
# no finance data skip stock RGBP
# no finance data skip stock WDDD
# no finance data skip stock INQD
# no finance data skip stock AASP
# no finance data skip stock OILCF
# no finance data skip stock STAF
# no finance data skip stock GMDAQ
# no finance data skip stock MWRK
# no finance data skip stock PDRO
# no finance data skip stock NVGT
# no finance data skip stock MGON
# no finance data skip stock DIGP
# no finance data skip stock TMIN
# no finance data skip stock PTCO
# no finance data skip stock IMHC
# no finance data skip stock GMER
# no finance data skip stock YCRM
# no finance data skip stock STQN
# no finance data skip stock CBNT
# no finance data skip stock HLCO
# no finance data skip stock VPER
# no finance data skip stock CYAN
# no finance data skip stock ARRT
# no finance data skip stock LQWC
# no finance data skip stock AMMJ
# no finance data skip stock OSAP
# no finance data skip stock CRCE
# no finance data skip stock LGHL
# no finance data skip stock HGYN
# no finance data skip stock PRSI
# no finance data skip stock DLOC
# no finance data skip stock NIMU
# no finance data skip stock GRVE
# no finance data skip stock VRVR
# no finance data skip stock CAMG
# no finance data skip stock ALDS
# no finance data skip stock CHJI
# no finance data skip stock CANOQ
# no finance data skip stock EBYH
# no finance data skip stock HIGR
# no finance data skip stock CBDS
# no finance data skip stock NUGL
# no finance data skip stock SRSG
# no finance data skip stock FECOF
# no finance data skip stock STRG
# no finance data skip stock BITTF
# no finance data skip stock GFOO
# no finance data skip stock PCYN
# no finance data skip stock QLGN
# no finance data skip stock EGMCF
# no finance data skip stock ACAN
# no finance data skip stock ASFT
# no finance data skip stock CORRQ
# no finance data skip stock FCIC
# no finance data skip stock ATAO
# no finance data skip stock BNCM
# no finance data skip stock RMESF
# no finance data skip stock RIBT
# no finance data skip stock NGTF
# no finance data skip stock HBUV
# no finance data skip stock MMND
# no finance data skip stock MEXGF
# no finance data skip stock MMNFF
# no finance data skip stock HENC
# no finance data skip stock LOWLF
# no finance data skip stock ELST
# no finance data skip stock PMVC
# no finance data skip stock RTON
# no finance data skip stock VEII
# no finance data skip stock SEQL
# no finance data skip stock FSTJ
# no finance data skip stock LADX
# no finance data skip stock BOTH
# no finance data skip stock FRZT
# no finance data skip stock GSTX
# no finance data skip stock JPPYY
# no finance data skip stock RCIT
# no finance data skip stock WARM
# no finance data skip stock CRCW
# no finance data skip stock CANB
# no finance data skip stock MRNJ
# no finance data skip stock TPPM
# no finance data skip stock HIRU
# no finance data skip stock CNNN
# no finance data skip stock HHHEF
# no finance data skip stock NSTD
# no finance data skip stock MGTI
# no finance data skip stock VEST
# no finance data skip stock NVIVQ
# no finance data skip stock SUNWQ
# no finance data skip stock WINSF
# no finance data skip stock GIGA
# no finance data skip stock AHRO
# no finance data skip stock SMCE
# no finance data skip stock LNTO
# no finance data skip stock ENMI
# no finance data skip stock NHMD
# no finance data skip stock SING
# no finance data skip stock GNTOF
# no finance data skip stock JKSM
# no finance data skip stock MNTR
# no finance data skip stock PAXH
# no finance data skip stock GRST
# no finance data skip stock AURI
# no finance data skip stock NXEN
# no finance data skip stock KRFG
# no finance data skip stock CGAC
# no finance data skip stock ABQQ
# no finance data skip stock ABNAF
# no finance data skip stock BFYW
# no finance data skip stock IPIX
# no finance data skip stock CSUI
# no finance data skip stock GSPI
# no finance data skip stock USAQ
# no finance data skip stock NTRR
# no finance data skip stock YBCN
# no finance data skip stock ADIA
# no finance data skip stock KAYS
# no finance data skip stock NSTC
# no finance data skip stock NRHI
# no finance data skip stock PTNYF
# no finance data skip stock INUMF
# no finance data skip stock LSMG
# no finance data skip stock FHSEY
# no finance data skip stock NWCN
# no finance data skip stock MMEX
# no finance data skip stock ZRFY
# no finance data skip stock DREM
# no finance data skip stock MLRT
# no finance data skip stock ETCK
# no finance data skip stock AGTX
# no finance data skip stock ARVLF
# no finance data skip stock DRFS
# no finance data skip stock MRPT
# no finance data skip stock ZAAG
# no finance data skip stock HWKE
# no finance data skip stock BLPG
# no finance data skip stock NMRD
# no finance data skip stock MDWK
# no finance data skip stock VGFCQ
# no finance data skip stock GMPW
# no finance data skip stock EEGI
# no finance data skip stock AUDAQ
# no finance data skip stock CBIA
# no finance data skip stock CMGO
# no finance data skip stock SATT
# no finance data skip stock DCFCQ
# no finance data skip stock FLXT
# no finance data skip stock IGEN
# no finance data skip stock VRTC
# no finance data skip stock RAKR
# no finance data skip stock AVPMF
# no finance data skip stock RDAR
# no finance data skip stock MMMW
# no finance data skip stock EDGM
# no finance data skip stock ONCI
# no finance data skip stock KEGS
# no finance data skip stock CSTF
# no finance data skip stock BOTY
# no finance data skip stock CRTD
# no finance data skip stock NIHK
# no finance data skip stock REOS
# no finance data skip stock TLIF
# no finance data skip stock ISCO
# no finance data skip stock MCOM
# no finance data skip stock RKFL
# no finance data skip stock GMBL
# ...
# 2022-06-29 16:00:00.000 TMDX     -22.630060  -9.824786             69.928366
# 2024-03-30 16:00:00.000 TMDX                -1318.481518
# 2022-06-29 16:00:00.000 MIRM                  -42.850471
# 2022-09-29 16:00:00.000 MIRM                 -162.047753
# 2022-12-30 16:00:00.006 MIRM                   -0.478064
# 2023-03-30 16:00:00.000 MIRM                   11.915905
# 2023-06-29 16:00:00.000 MIRM                  107.354506
# 2023-09-29 16:00:00.000 MIRM                  -35.252944
# 2023-12-30 16:00:00.004 MIRM                   18.350481
# 2024-03-30 16:00:00.000 MIRM                  -65.856722
# 2022-12-30 16:00:00.004 AZUL                  -69.940027
# 2023-12-30 16:00:00.005 AZUL                  -78.029350
# 2022-12-30 16:00:00.005 YALA                    3.819954
# 2023-12-30 16:00:00.005 YALA                  229.501857
# 2022-12-30 16:00:00.006 TIGR                 -622.214599
# 2023-12-30 16:00:00.006 TIGR                 -117.911429
# 2022-12-30 16:00:00.006 JFIN                 1079.599505
# 2023-12-30 16:00:00.006 JFIN                  353.024608
# 2022-12-30 16:00:00.004 XYF                   244.709584
# 2023-12-30 16:00:00.005 XYF                  -128.829322
# 2022-06-29 16:00:00.000 ALAR                  -36.953484
# 2022-12-30 16:00:00.005 ALAR                   22.194093
# 2023-06-29 16:00:00.000 ALAR                   70.353982
# 2023-12-30 16:00:00.005 ALAR                 -152.944902
# 2022-12-30 16:00:00.005 BROG                 -135.090296
# 2023-06-29 16:00:00.000 BROG                  117.771344
# 2022-12-30 16:00:00.004 BYSI                   82.366543
# 2023-12-30 16:00:00.006 BYSI                    8.960929
# 2022-12-30 16:00:00.006 IH                    391.033814
# 2023-12-30 16:00:00.006 IH                   -161.899535
# 2022-06-29 16:00:00.004 HYW                   283.776440
# 2023-06-29 16:00:00.005 HYW                   308.775746
# 2022-06-29 16:00:00.005 IMRN                  -50.263680
# 2022-12-30 16:00:00.000 IMRN                  -76.404183
# 2023-06-29 16:00:00.005 IMRN                  109.031364
# 2023-12-30 16:00:00.000 IMRN                  -27.365189
# 2022-12-30 16:00:00.005 BROGW                -135.090296
# 2023-06-29 16:00:00.000 BROGW                 117.771344

# %%
from utils.us_equity_utils import *

# symbols = ["AMZN", "AAPL", "NFLX", "GOOG"]
symbols = result[0].index
# symbols = us_equity_symbol_load().head(2000)
# data = us_equity_daily_data_load(symbols = symbols, option = 'close')

start_date = '2024-01-29'
end_date = '2024-07-08'

data = us_equity_daily_data_load(symbols = symbols, start_date = start_date, end_date = end_date, option = 'close')
data = pd.DataFrame(data)
data = data.sub(data.iloc[0, :], axis=1).div(data.iloc[0, :], axis=1) * 100

sorted_columns = data.iloc[-1].sort_values(ascending=False).index
data = data[sorted_columns]
# data = data.loc[:, data.iloc[-1] > 30]

file = sector_name + start_date + "_" + end_date + ".csv"
folder = us_equity_research_folder(sub_folder = "price", file_name = file, data = data)

print(data.tail(1).transpose())

# Convert the DataFrame to long format
df_long = data.reset_index().melt(id_vars='date', var_name='variable', value_name='value')

# Create a line plot using Seaborn's relplot
g = sns.relplot(
    data=df_long, 
    x='date', 
    y='value', 
    hue='variable', 
    kind='line',
    style='variable',  # Different line styles for each variable
    height=10,    # Height of each facet
    aspect=1.5  # Aspect ratio of each facet
)


# Rotate x-axis labels and set only a subset of ticks
for ax in g.axes.flat:
    x = data.index[1:-1:20]
    ax.set_xticks(x)  # Set the desired tick positions
    ax.set_xticklabels(x)  # Set the desired tick labels
    for label in ax.get_xticklabels():
        label.set_rotation(90)
# Out:
# lack of some trade date skip  SEAT
# lack of some trade date skip  SEATW
# lack of some trade date skip  ELTK
# lack of some trade date skip  OSIS
# lack of some trade date skip  NX
# lack of some trade date skip  BELFB
# lack of some trade date skip  BELFA
# lack of some trade date skip  VICR
# lack of some trade date skip  CTS
# lack of some trade date skip  ESE
# lack of some trade date skip  LYTS
# lack of some trade date skip  CNXN
# lack of some trade date skip  VPG
# lack of some trade date skip  AWIN
# lack of some trade date skip  AWINW
# lack of some trade date skip  LINK
# lack of some trade date skip  HLP
# lack of some trade date skip  LASE
# lack of some trade date skip  MPX
# lack of some trade date skip  ROG
# lack of some trade date skip  SGML
# lack of some trade date skip  DSWL
# lack of some trade date skip  LUNA
# lack of some trade date skip  FARO
# lack of some trade date skip  HBB
# lack of some trade date skip  MIND
# lack of some trade date skip  MINDP
# lack of some trade date skip  ELSE
# lack of some trade date skip  MLAB
# lack of some trade date skip  MVSTW
# lack of some trade date skip  MVST
# lack of some trade date skip  AMLI
# lack of some trade date skip  XMTR
# lack of some trade date skip  SONO
# lack of some trade date skip  DSGR
# lack of some trade date skip  DAIO
# lack of some trade date skip  BHE
# lack of some trade date skip  GAUZ
# lack of some trade date skip  ZEPP
# lack of some trade date skip  SCSC
# lack of some trade date skip  PLXS
# lack of some trade date skip  POCI
# lack of some trade date skip  NNAVW
# lack of some trade date skip  UEIC
# lack of some trade date skip  NN
# lack of some trade date skip  GPRO
# lack of some trade date skip  VZIO
# lack of some trade date skip  OB
# lack of some trade date skip  OUST
# lack of some trade date skip  TTMI
# lack of some trade date skip  ENVX
# failed to load equity WTMAR
# lack of some trade date skip  RELL
# lack of some trade date skip  VIOT
# lack of some trade date skip  XPON
# lack of some trade date skip  KOPN
# lack of some trade date skip  GNSS
# lack of some trade date skip  CEADW
# lack of some trade date skip  CEAD
# lack of some trade date skip  WRAP
# lack of some trade date skip  DFLI
# lack of some trade date skip  DFLIW
# lack of some trade date skip  IRBT
# lack of some trade date skip  MEI
# lack of some trade date skip  ATER
# lack of some trade date skip  DPRO
# lack of some trade date skip  VOXX
# lack of some trade date skip  WATT
# lack of some trade date skip  OST
# date  2024-07-08
# CLS    81.781873
# COHR   56.447992
# GLW    38.202246
# APH    34.036471
# ITRI   33.014683
# SANM   31.404301
# GRMN   29.027874
# FLEX   28.590023
# CGNX   24.572025
# MKSI   20.834813
# AAPL   18.823352
# FN     13.727704
# TRMB    9.131444
# VNT     8.810950
# ST      7.944056
# AVT     7.920169
# FER     6.973688
# LFUS    5.698877
# ARW     4.477477
# TEL     3.425555
# LPL    -1.096485
# NOVT   -1.238826
# FTV    -1.539699
# TDY   -10.795260
# SONY  -10.923681
# JBL   -11.502576
# KEYS  -13.324544
